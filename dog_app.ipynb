# %% [markdown]
# # Convolutional Neural Networks
#
# ## Project: Write an Algorithm for a Dog Identification App
#
# ---
#
# In this notebook, some template code has already been provided for you, and you will need to implement additional functionality to successfully complete this project. You will not need to modify the included code beyond what is requested. Sections that begin with **'(IMPLEMENTATION)'** in the header indicate that the following block of code will require additional functionality which you must provide. Instructions will be provided for each section, and the specifics of the implementation are marked in the code block with a 'TODO' statement. Please be sure to read the instructions carefully!
#
# > **Note**: Once you have completed all of the code implementations, you need to finalize your work by exporting the Jupyter Notebook as an HTML document. Before exporting the notebook to html, all of the code cells need to have been run so that reviewers can see the final implementation and output. You can then export the notebook by using the menu above and navigating to **File -> Download as -> HTML (.html)**. Include the finished document along with this notebook as your submission.
#
# In addition to implementing code, there will be questions that you must answer which relate to the project and your implementation. Each section where you will answer a question is preceded by a **'Question X'** header. Carefully read each question and provide thorough answers in the following text boxes that begin with **'Answer:'**. Your project submission will be evaluated based on your answers to each of the questions and the implementation you provide.
#
# >**Note:** Code and Markdown cells can be executed using the **Shift + Enter** keyboard shortcut.  Markdown cells can be edited by double-clicking the cell to enter edit mode.
#
# The rubric contains _optional_ "Stand Out Suggestions" for enhancing the project beyond the minimum requirements. If you decide to pursue the "Stand Out Suggestions", you should include the code in this Jupyter notebook.
#
#
#
# ---
# ### Why We're Here
#
# In this notebook, you will make the first steps towards developing an algorithm that could be used as part of a mobile or web app.  At the end of this project, your code will accept any user-supplied image as input.  If a dog is detected in the image, it will provide an estimate of the dog's breed.  If a human is detected, it will provide an estimate of the dog breed that is most resembling.  The image below displays potential sample output of your finished project (... but we expect that each student's algorithm will behave differently!).
#
# ![Sample Dog Output](images/sample_dog_output.png)
#
# In this real-world setting, you will need to piece together a series of models to perform different tasks; for instance, the algorithm that detects humans in an image will be different from the CNN that infers dog breed.  There are many points of possible failure, and no perfect algorithm exists.  Your imperfect solution will nonetheless create a fun user experience!
#
# ### The Road Ahead
#
# We break the notebook into separate steps.  Feel free to use the links below to navigate the notebook.
#
# * [Step 0](#step0): Import Datasets
# * [Step 1](#step1): Detect Humans
# * [Step 2](#step2): Detect Dogs
# * [Step 3](#step3): Create a CNN to Classify Dog Breeds (from Scratch)
# * [Step 4](#step4): Create a CNN to Classify Dog Breeds (using Transfer Learning)
# * [Step 5](#step5): Write your Algorithm
# * [Step 6](#step6): Test Your Algorithm
#
# ---
# <a id='step0'></a>
# ## Step 0: Import Datasets
#
# Make sure that you've downloaded the required human and dog datasets:
# * Download the [dog dataset](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/dogImages.zip).  Unzip the folder and place it in this project's home directory, at the location `/dog_images`.
#
# * Download the [human dataset](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/lfw.zip).  Unzip the folder and place it in the home directory, at location `/lfw`.
#
# *Note: If you are using a Windows machine, you are encouraged to use [7zip](http://www.7-zip.org/) to extract the folder.*
#
# In the code cell below, we save the file paths for both the human (LFW) dataset and dog dataset in the numpy arrays `human_files` and `dog_files`.

# %%
# !pip install Pillow==5.4.1
# Out:
# Collecting Pillow==5.4.1
#   Downloading https://files.pythonhosted.org/packages/85/5e/e91792f198bbc5a0d7d3055ad552bc4062942d27eaf75c3e2783cf64eae5/Pillow-5.4.1-cp36-cp36m-manylinux1_x86_64.whl (2.0MB)
#     100% |████████████████████████████████| 2.0MB 13.5MB/s ta 0:00:01
# scikit-image 0.14.2 has requirement dask[array]>=1.0.0, but you'll have dask 0.16.1 which is incompatible.
# Installing collected packages: Pillow
#   Found existing installation: Pillow 5.2.0
#     Uninstalling Pillow-5.2.0:
#       Successfully uninstalled Pillow-5.2.0
# Successfully installed Pillow-5.4.1

# %%
from PIL import Image
import PIL
from PIL import ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True
PIL.__version__
# Out:
# '5.4.1'

# %%
import numpy as np
from glob import glob

# load filenames for human and dog images
human_files = np.array(glob("/data/lfw/*/*"))
dog_files = np.array(glob("/data/dog_images/*/*/*"))

# print number of images in each dataset
print('There are %d total human images.' % len(human_files))
print('There are %d total dog images.' % len(dog_files))
# Out:
# There are 13233 total human images.
# There are 8351 total dog images.

# %% [markdown]
# <a id='step1'></a>
# ## Step 1: Detect Humans
#
# In this section, we use OpenCV's implementation of [Haar feature-based cascade classifiers](http://docs.opencv.org/trunk/d7/d8b/tutorial_py_face_detection.html) to detect human faces in images.
#
# OpenCV provides many pre-trained face detectors, stored as XML files on [github](https://github.com/opencv/opencv/tree/master/data/haarcascades).  We have downloaded one of these detectors and stored it in the `haarcascades` directory.  In the next code cell, we demonstrate how to use this detector to find human faces in a sample image.

# %%
import cv2                
import matplotlib.pyplot as plt                        
# %matplotlib inline                               

# extract pre-trained face detector
face_cascade = cv2.CascadeClassifier('haarcascades/haarcascade_frontalface_alt.xml')

# load color (BGR) image
img = cv2.imread(human_files[0])
# convert BGR image to grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# find faces in image
faces = face_cascade.detectMultiScale(gray)

# print number of faces detected in the image
print('Number of faces detected:', len(faces))

# get bounding box for each detected face
for (x,y,w,h) in faces:
    # add bounding box to color image
    cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    
# convert BGR image to RGB for plotting
cv_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# display the image, along with bounding box
plt.imshow(cv_rgb)
plt.show()
# Out:
# Number of faces detected: 1

# %% [markdown]
# Before using any of the face detectors, it is standard procedure to convert the images to grayscale.  The `detectMultiScale` function executes the classifier stored in `face_cascade` and takes the grayscale image as a parameter.
#
# In the above code, `faces` is a numpy array of detected faces, where each row corresponds to a detected face.  Each detected face is a 1D array with four entries that specifies the bounding box of the detected face.  The first two entries in the array (extracted in the above code as `x` and `y`) specify the horizontal and vertical positions of the top left corner of the bounding box.  The last two entries in the array (extracted here as `w` and `h`) specify the width and height of the box.
#
# ### Write a Human Face Detector
#
# We can use this procedure to write a function that returns `True` if a human face is detected in an image and `False` otherwise.  This function, aptly named `face_detector`, takes a string-valued file path to an image as input and appears in the code block below.

# %%
# returns "True" if face is detected in image stored at img_path
def face_detector(img_path):
    img = cv2.imread(img_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray)
    return len(faces) > 0

# %%
face_detector(human_files[3])
# Out:
# True

# %% [markdown]
# ### (IMPLEMENTATION) Assess the Human Face Detector
#
# __Question 1:__ Use the code cell below to test the performance of the `face_detector` function.
# - What percentage of the first 100 images in `human_files` have a detected human face?
# - What percentage of the first 100 images in `dog_files` have a detected human face?
#
# Ideally, we would like 100% of human images with a detected face and 0% of dog images with a detected face.  You will see that our algorithm falls short of this goal, but still gives acceptable performance.  We extract the file paths for the first 100 images from each of the datasets and store them in the numpy arrays `human_files_short` and `dog_files_short`.

# %% [markdown]
# __Answer:__
# (You can print out your results and/or write your percentages in this cell)

# %%
from tqdm import tqdm

human_files_short = human_files[:100]
dog_files_short = dog_files[:100]

#-#-# Do NOT modify the code above this line. #-#-#

## TODO: Test the performance of the face_detector algorithm 
## on the images in human_files_short and dog_files_short.
humans = 0
for img_path in human_files_short:
    if face_detector(img_path):
        humans+=1

dogs = 0
for img_path in dog_files_short:
    if face_detector(img_path):
        dogs+=1
        
print(f"{humans} humans were detected as humans and {dogs} dogs where detected as humans")
# Out:
# 98 humans were detected as humans and 17 dogs where detected as humans

# %%
# Here's a more pythonic one line solution
#sum(face_detector(img_path) for img_path in tqdm(human_files_short))

# %%
#sum(face_detector(img_path) for img_path in dog_files_short)

# %% [markdown]
# We suggest the face detector from OpenCV as a potential way to detect human images in your algorithm, but you are free to explore other approaches, especially approaches that make use of deep learning :).  Please use the code cell below to design and test your own face detection algorithm.  If you decide to pursue this _optional_ task, report performance on `human_files_short` and `dog_files_short`.

# %%
### (Optional) 
### TODO: Test performance of anotherface detection algorithm.
### Feel free to use as many code cells as needed.

# %% [markdown]
# ---
# <a id='step2'></a>
# ## Step 2: Detect Dogs
#
# In this section, we use a [pre-trained model](http://pytorch.org/docs/master/torchvision/models.html) to detect dogs in images.
#
# ### Obtain Pre-trained VGG-16 Model
#
# The code cell below downloads the VGG-16 model, along with weights that have been trained on [ImageNet](http://www.image-net.org/), a very large, very popular dataset used for image classification and other vision tasks.  ImageNet contains over 10 million URLs, each linking to an image containing an object from one of [1000 categories](https://gist.github.com/yrevar/942d3a0ac09ec9e5eb3a).

# %%
import torch
import torchvision.models as models

# define VGG16 model
VGG16 = models.vgg16(pretrained=True)

# check if CUDA is available
use_cuda = torch.cuda.is_available()

# move model to GPU if CUDA is available
if use_cuda:
    VGG16 = VGG16.cuda()
# Out:
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.torch/models/vgg16-397923af.pth
# 100%|██████████| 553433881/553433881 [00:13<00:00, 41152857.66it/s]

# %% [markdown]
# Given an image, this pre-trained VGG-16 model returns a prediction (derived from the 1000 possible categories in ImageNet) for the object that is contained in the image.

# %% [markdown]
# ### (IMPLEMENTATION) Making Predictions with a Pre-trained Model
#
# In the next code cell, you will write a function that accepts a path to an image (such as `'dogImages/train/001.Affenpinscher/Affenpinscher_00001.jpg'`) as input and returns the index corresponding to the ImageNet class that is predicted by the pre-trained VGG-16 model.  The output should always be an integer between 0 and 999, inclusive.
#
# Before writing the function, make sure that you take the time to learn  how to appropriately pre-process tensors for pre-trained models in the [PyTorch documentation](http://pytorch.org/docs/stable/torchvision/models.html).

# %%
from PIL import Image
import torchvision.transforms as transforms

def VGG16_predict(img_path):
    '''
    Use pre-trained VGG-16 model to obtain index corresponding to 
    predicted ImageNet class for image at specified path
    
    Args:
        img_path: path to an image
        
    Returns:
        Index corresponding to VGG-16 model's prediction
    '''
    
    ## TODO: Complete the function.
    ## Load and pre-process an image from the given img_path
    ## Return the *index* of the predicted class for that image
    normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                 std=[0.229, 0.224, 0.225])
    transform = transforms.Compose([
        transforms.Resize(224),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        normalize
    ])
    
    
    img = Image.open(img_path)
    img = transform(img)
    # Add batch dimension
    img = img.unsqueeze(0)
    if use_cuda:
        img = img.cuda()
    pred = VGG16.forward(img)
    _, class_idx = pred.max(1)
    
    return class_idx.item() # predicted class index

# %%
img_path = '/data/dog_images/train/059.Doberman_pinscher/Doberman_pinscher_04192.jpg'
img = Image.open(img_path); img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=536x640 at 0x7F51BD2CE208>

# %%
tr = transforms.Compose([
    transforms.Resize(224),
    transforms.CenterCrop(224),
])

# %%
tr(img)
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F51BD34C710>

# %% [markdown]
# ### (IMPLEMENTATION) Write a Dog Detector
#
# While looking at the [dictionary](https://gist.github.com/yrevar/942d3a0ac09ec9e5eb3a), you will notice that the categories corresponding to dogs appear in an uninterrupted sequence and correspond to dictionary keys 151-268, inclusive, to include all categories from `'Chihuahua'` to `'Mexican hairless'`.  Thus, in order to check to see if an image is predicted to contain a dog by the pre-trained VGG-16 model, we need only check if the pre-trained model predicts an index between 151 and 268 (inclusive).
#
# Use these ideas to complete the `dog_detector` function below, which returns `True` if a dog is detected in an image (and `False` if not).

# %%
### returns "True" if a dog is detected in the image stored at img_path
def dog_detector(img_path, check_dog=False):
    n = VGG16_predict(img_path)
    return n>=151 and n<=268

# %% [markdown]
# ### (IMPLEMENTATION) Assess the Dog Detector
#
# __Question 2:__ Use the code cell below to test the performance of your `dog_detector` function.
# - What percentage of the images in `human_files_short` have a detected dog?
# - What percentage of the images in `dog_files_short` have a detected dog?

# %% [markdown]
# __Answer:__

# %%
### TODO: Test the performance of the dog_detector function
### on the images in human_files_short and dog_files_short.

# Number of humans detected as dogs
sum(dog_detector(img_path) for img_path in tqdm(human_files_short))
# Out:
# 100%|██████████| 100/100 [00:03<00:00, 28.78it/s]
# 0

# %%
# Number of dogs detected as dogs
sum(dog_detector(img_path) for img_path in tqdm(dog_files_short))
# Out:
# 100%|██████████| 100/100 [00:06<00:00, 14.52it/s]
# 100

# %% [markdown]
# We suggest VGG-16 as a potential network to detect dog images in your algorithm, but you are free to explore other pre-trained networks (such as [Inception-v3](http://pytorch.org/docs/master/torchvision/models.html#inception-v3), [ResNet-50](http://pytorch.org/docs/master/torchvision/models.html#id3), etc).  Please use the code cell below to test other pre-trained PyTorch models.  If you decide to pursue this _optional_ task, report performance on `human_files_short` and `dog_files_short`.

# %%
### (Optional) 
### TODO: Report the performance of another pre-trained network.
### Feel free to use as many code cells as needed.

# %% [markdown]
# ---
# <a id='step3'></a>
# ## Step 3: Create a CNN to Classify Dog Breeds (from Scratch)
#
# Now that we have functions for detecting humans and dogs in images, we need a way to predict breed from images.  In this step, you will create a CNN that classifies dog breeds.  You must create your CNN _from scratch_ (so, you can't use transfer learning _yet_!), and you must attain a test accuracy of at least 10%.  In Step 4 of this notebook, you will have the opportunity to use transfer learning to create a CNN that attains greatly improved accuracy.
#
# We mention that the task of assigning breed to dogs from images is considered exceptionally challenging.  To see why, consider that *even a human* would have trouble distinguishing between a Brittany and a Welsh Springer Spaniel.
#
# Brittany | Welsh Springer Spaniel
# - | -
# <img src="images/Brittany_02625.jpg" width="100"> | <img src="images/Welsh_springer_spaniel_08203.jpg" width="200">
#
# It is not difficult to find other dog breed pairs with minimal inter-class variation (for instance, Curly-Coated Retrievers and American Water Spaniels).
#
# Curly-Coated Retriever | American Water Spaniel
# - | -
# <img src="images/Curly-coated_retriever_03896.jpg" width="200"> | <img src="images/American_water_spaniel_00648.jpg" width="200">
#
#
# Likewise, recall that labradors come in yellow, chocolate, and black.  Your vision-based algorithm will have to conquer this high intra-class variation to determine how to classify all of these different shades as the same breed.
#
# Yellow Labrador | Chocolate Labrador | Black Labrador
# - | -
# <img src="images/Labrador_retriever_06457.jpg" width="150"> | <img src="images/Labrador_retriever_06455.jpg" width="240"> | <img src="images/Labrador_retriever_06449.jpg" width="220">
#
# We also mention that random chance presents an exceptionally low bar: setting aside the fact that the classes are slightly imabalanced, a random guess will provide a correct answer roughly 1 in 133 times, which corresponds to an accuracy of less than 1%.
#
# Remember that the practice is far ahead of the theory in deep learning.  Experiment with many different architectures, and trust your intuition.  And, of course, have fun!
#
# ### (IMPLEMENTATION) Specify Data Loaders for the Dog Dataset
#
# Use the code cell below to write three separate [data loaders](http://pytorch.org/docs/stable/data.html#torch.utils.data.DataLoader) for the training, validation, and test datasets of dog images (located at `dog_images/train`, `dog_images/valid`, and `dog_images/test`, respectively).  You may find [this documentation on custom datasets](http://pytorch.org/docs/stable/torchvision/datasets.html) to be a useful resource.  If you are interested in augmenting your training and/or validation data, check out the wide variety of [transforms](http://pytorch.org/docs/stable/torchvision/transforms.html?highlight=transform)!

# %%
ls /data/dog_images
# Out:
# test/  train/  valid/

# %%
import os
from torchvision import datasets

### TODO: Write data loaders for training, validation, and test sets
## Specify appropriate transformimagenet_data = torchvision.datasets.ImageFolder('path/to/imagenet_root/')

BATCH_SIZE = 32
normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406],
                             std=[0.229, 0.224, 0.225])

transform = transforms.Compose([
    transforms.Resize(224),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    normalize])


train_set = datasets.ImageFolder("/data/dog_images/train", transform=transform)    

train_loader = torch.utils.data.DataLoader(train_set,
                                          batch_size=BATCH_SIZE,
                                          shuffle=True)

valid_set = datasets.ImageFolder("/data/dog_images/valid", transform=transform)    

valid_loader = torch.utils.data.DataLoader(train_set,
                                          batch_size=BATCH_SIZE)

test_set = datasets.ImageFolder("/data/dog_images/test", transform=transform)    

test_loader = torch.utils.data.DataLoader(train_set,
                                          batch_size=BATCH_SIZE)

loaders = {'train': train_loader, 'valid': valid_loader, 'test': test_loader}

# %%
#img, label = next(iter(train_loader))

# %% [markdown]
# **Question 3:** Describe your chosen procedure for preprocessing the data.
# - How does your code resize the images (by cropping, stretching, etc)?  What size did you pick for the input tensor, and why?
# - Did you decide to augment the dataset?  If so, how (through translations, flips, rotations, etc)?  If not, why not?

# %% [markdown]
# **Answer**:

# %% [markdown]
# ### (IMPLEMENTATION) Model Architecture
#
# Create a CNN to classify dog breed.  Use the template in the code cell below.

# %%
torch.cuda.empty_cache()

# %%
import torch.nn as nn
import torch.nn.functional as F

# define the CNN architecture
class Net(nn.Module):
    ### TODO: choose an architecture, and complete the class
    def __init__(self):
        super(Net, self).__init__()
        ## Define layers of a CNN
        self.conv = nn.Conv2d(3,16,5, stride=2)
        self.maxpool = nn.MaxPool2d(2,2)
        self.fc = nn.Linear(55*55*16,133)
    
    def forward(self, x):
        ## Define forward behavior
        x = self.maxpool(F.relu(self.conv(x)))
        x = x.view(x.size(0), -1)
        x = self.fc(x)
        return x

#-#-# You so NOT have to modify the code below this line. #-#-#

# instantiate the CNN
model_scratch = Net()

# move tensors to GPU if CUDA is available
if use_cuda:
    model_scratch.cuda()

# %% [markdown]
# __Question 4:__ Outline the steps you took to get to your final CNN architecture and your reasoning at each step.

# %% [markdown]
# __Answer:__

# %% [markdown]
# ### (IMPLEMENTATION) Specify Loss Function and Optimizer
#
# Use the next code cell to specify a [loss function](http://pytorch.org/docs/stable/nn.html#loss-functions) and [optimizer](http://pytorch.org/docs/stable/optim.html).  Save the chosen loss function as `criterion_scratch`, and the optimizer as `optimizer_scratch` below.

# %%
import torch.optim as optim

### TODO: select loss function
criterion_scratch = nn.CrossEntropyLoss()

### TODO: select optimizer
optimizer_scratch = optim.SGD(model_scratch.parameters(), lr=1e-3)

# %% [markdown]
# ### (IMPLEMENTATION) Train and Validate the Model
#
# Train and validate your model in the code cell below.  [Save the final model parameters](http://pytorch.org/docs/master/notes/serialization.html) at filepath `'model_scratch.pt'`.

# %%
model_scratch
# Out:
# Net(
#   (conv): Conv2d(3, 16, kernel_size=(5, 5), stride=(2, 2))
#   (maxpool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc): Linear(in_features=48400, out_features=133, bias=True)
# )

# %%
def train(n_epochs, loaders, model, optimizer, criterion, use_cuda, save_path, valid_loss_min = np.Inf):
    """returns trained model"""
    # initialize tracker for minimum validation loss
    
    
    for epoch in range(1, n_epochs+1):
        # initialize variables to monitor training and validation loss
        train_loss = 0.0
        valid_loss = 0.0
        
        ###################
        # train the model #
        ###################
        model.train()
        for batch_idx, (data, target) in enumerate(loaders['train']):
            # move to GPU
            if use_cuda:
                data, target = data.cuda(), target.cuda()
            ## find the loss and update the model parameters accordingly
            ## record the average training loss, using something like
            ## train_loss = train_loss + ((1 / (batch_idx + 1)) * (loss.data - train_loss))
            optimizer.zero_grad()
            output = model(data)
            loss = criterion(output, target)
            loss.backward()
            optimizer.step()
            
            #train_loss += loss.item()*data.size(0)
            train_loss = train_loss + ((1 / (batch_idx + 1)) * (loss.data - train_loss))
            print(f'Batch id {batch_idx}, Training Loss = {train_loss}')
            
        ######################    
        # validate the model #
        ######################
        model.eval()
        with torch.no_grad():
            for batch_idx, (data, target) in enumerate(loaders['valid']):
                # move to GPU
                if use_cuda:
                    data, target = data.cuda(), target.cuda()
                ## update the average validation loss

                output = model(data)

                loss = criterion(output, target)            
                #valid_loss += loss.item()*data.size(0)
                valid_loss = valid_loss + ((1 / (batch_idx + 1)) * (loss.data - valid_loss))

            #caluclate average losses    
            #train_loss = train_loss/len(loaders['train'].dataset)
            #valid_loss = valid_loss/len(loaders['valid'].dataset)

            # print training/validation statistics 
            print('Finished epoch: {} \tTraining Loss: {:.6f} \tValidation Loss: {:.6f}'.format(
                epoch, 
                train_loss,
                valid_loss
                ))

            ## TODO: save the model if validation loss has decreased
            if valid_loss <= valid_loss_min:
                print('Validation loss decreased ({:.6f} --> {:.6f}).  Saving model ...'.format(
                valid_loss_min,
                valid_loss))
                torch.save(model.state_dict(), save_path)
                valid_loss_min = valid_loss
            
    # return trained model
    return model

# %%
# load the model that got the best validation accuracy
model_scratch.load_state_dict(torch.load('model_scratch.pt'))

# train the model
model_scratch = train(3, loaders, model_scratch, optimizer_scratch, 
                      criterion_scratch, use_cuda, 'model_scratch.pt', valid_loss_min=2.930927)
# Out:
# Batch id 0, Training Loss = 3.7849133014678955
# Batch id 1, Training Loss = 3.851872205734253
# Batch id 2, Training Loss = 3.797107696533203
# Batch id 3, Training Loss = 3.830251932144165
# Batch id 4, Training Loss = 3.836364507675171
# Batch id 5, Training Loss = 3.8232598304748535
# Batch id 6, Training Loss = 3.8439831733703613
# Batch id 7, Training Loss = 3.8241822719573975
# Batch id 8, Training Loss = 3.8166000843048096
# Batch id 9, Training Loss = 3.8137662410736084
# Batch id 10, Training Loss = 3.794051170349121
# Batch id 11, Training Loss = 3.8126354217529297
# Batch id 12, Training Loss = 3.7862536907196045
# Batch id 13, Training Loss = 3.8226444721221924
# Batch id 14, Training Loss = 3.8237831592559814
# Batch id 15, Training Loss = 3.823005199432373
# Batch id 16, Training Loss = 3.8376777172088623
# Batch id 17, Training Loss = 3.8272745609283447
# Batch id 18, Training Loss = 3.821103572845459
# Batch id 19, Training Loss = 3.833264112472534
# Batch id 20, Training Loss = 3.8412349224090576
# Batch id 21, Training Loss = 3.840933322906494
# Batch id 22, Training Loss = 3.8292837142944336
# Batch id 23, Training Loss = 3.8328664302825928
# Batch id 24, Training Loss = 3.827167272567749
# Batch id 25, Training Loss = 3.8259739875793457
# Batch id 26, Training Loss = 3.827991008758545
# Batch id 27, Training Loss = 3.8268096446990967
# Batch id 28, Training Loss = 3.8306455612182617
# Batch id 29, Training Loss = 3.8329617977142334
# Batch id 30, Training Loss = 3.840437173843384
# Batch id 31, Training Loss = 3.8396482467651367
# Batch id 32, Training Loss = 3.8425614833831787
# Batch id 33, Training Loss = 3.832995891571045
# Batch id 34, Training Loss = 3.8372926712036133
# Batch id 35, Training Loss = 3.840207815170288
# Batch id 36, Training Loss = 3.8430299758911133
# Batch id 37, Training Loss = 3.8409719467163086
# Batch id 38, Training Loss = 3.845851182937622
# Batch id 39, Training Loss = 3.8343443870544434
# Batch id 40, Training Loss = 3.8349015712738037
# Batch id 41, Training Loss = 3.8301076889038086
# Batch id 42, Training Loss = 3.8301451206207275
# Batch id 43, Training Loss = 3.8321144580841064
# Batch id 44, Training Loss = 3.839747667312622
# Batch id 45, Training Loss = 3.8455498218536377
# Batch id 46, Training Loss = 3.84830379486084
# Batch id 47, Training Loss = 3.8508293628692627
# Batch id 48, Training Loss = 3.844379186630249
# Batch id 49, Training Loss = 3.84677791595459
# Batch id 50, Training Loss = 3.844723701477051
# Batch id 51, Training Loss = 3.8461050987243652
# Batch id 52, Training Loss = 3.8484222888946533
# Batch id 53, Training Loss = 3.8466265201568604
# Batch id 54, Training Loss = 3.8464741706848145
# Batch id 55, Training Loss = 3.847156524658203
# Batch id 56, Training Loss = 3.8482813835144043
# Batch id 57, Training Loss = 3.852254629135132
# Batch id 58, Training Loss = 3.8489065170288086
# Batch id 59, Training Loss = 3.851809024810791
# Batch id 60, Training Loss = 3.852902412414551
# Batch id 61, Training Loss = 3.852301597595215
# Batch id 62, Training Loss = 3.8530712127685547
# Batch id 63, Training Loss = 3.853569269180298
# Batch id 64, Training Loss = 3.852452278137207
# Batch id 65, Training Loss = 3.8541452884674072
# Batch id 66, Training Loss = 3.8513431549072266
# Batch id 67, Training Loss = 3.848947048187256
# Batch id 68, Training Loss = 3.8524832725524902
# Batch id 69, Training Loss = 3.851365089416504
# Batch id 70, Training Loss = 3.8546059131622314
# Batch id 71, Training Loss = 3.8539962768554688
# Batch id 72, Training Loss = 3.8519632816314697
# Batch id 73, Training Loss = 3.8504393100738525
# Batch id 74, Training Loss = 3.8488292694091797
# Batch id 75, Training Loss = 3.8474671840667725
# Batch id 76, Training Loss = 3.850691795349121
# Batch id 77, Training Loss = 3.851316452026367
# Batch id 78, Training Loss = 3.8520925045013428
# Batch id 79, Training Loss = 3.8508145809173584
# Batch id 80, Training Loss = 3.851006507873535
# Batch id 81, Training Loss = 3.8554341793060303
# Batch id 82, Training Loss = 3.8578743934631348
# Batch id 83, Training Loss = 3.8526782989501953
# Batch id 84, Training Loss = 3.856553554534912
# Batch id 85, Training Loss = 3.8546664714813232
# Batch id 86, Training Loss = 3.8525266647338867
# Batch id 87, Training Loss = 3.8534469604492188
# Batch id 88, Training Loss = 3.8537676334381104
# Batch id 89, Training Loss = 3.8545784950256348
# Batch id 90, Training Loss = 3.85355281829834
# Batch id 91, Training Loss = 3.856693983078003
# Batch id 92, Training Loss = 3.8557090759277344
# Batch id 93, Training Loss = 3.8567326068878174
# Batch id 94, Training Loss = 3.859520673751831
# Batch id 95, Training Loss = 3.857304096221924
# Batch id 96, Training Loss = 3.856776714324951
# Batch id 97, Training Loss = 3.857921838760376
# Batch id 98, Training Loss = 3.8553247451782227
# Batch id 99, Training Loss = 3.853003978729248
# Batch id 100, Training Loss = 3.8546128273010254
# Batch id 101, Training Loss = 3.856997489929199
# Batch id 102, Training Loss = 3.8549726009368896
# Batch id 103, Training Loss = 3.855226516723633
# Batch id 104, Training Loss = 3.8558576107025146
# Batch id 105, Training Loss = 3.8571102619171143
# Batch id 106, Training Loss = 3.8584113121032715
# Batch id 107, Training Loss = 3.8619368076324463
# Batch id 108, Training Loss = 3.864877462387085
# Batch id 109, Training Loss = 3.862057685852051
# Batch id 110, Training Loss = 3.859433174133301
# Batch id 111, Training Loss = 3.861758232116699
# Batch id 112, Training Loss = 3.861236095428467
# Batch id 113, Training Loss = 3.860720157623291
# Batch id 114, Training Loss = 3.8639585971832275
# Batch id 115, Training Loss = 3.8651044368743896
# Batch id 116, Training Loss = 3.867710828781128
# Batch id 117, Training Loss = 3.868095874786377
# Batch id 118, Training Loss = 3.870720386505127
# Batch id 119, Training Loss = 3.869490146636963
# Batch id 120, Training Loss = 3.8694114685058594
# Batch id 121, Training Loss = 3.8713550567626953
# Batch id 122, Training Loss = 3.869715690612793
# Batch id 123, Training Loss = 3.8678476810455322
# Batch id 124, Training Loss = 3.8689911365509033
# Batch id 125, Training Loss = 3.8694283962249756
# Batch id 126, Training Loss = 3.8715312480926514
# Batch id 127, Training Loss = 3.8699464797973633
# Batch id 128, Training Loss = 3.872650146484375
# Batch id 129, Training Loss = 3.8730223178863525
# Batch id 130, Training Loss = 3.8734004497528076
# Batch id 131, Training Loss = 3.8730692863464355
# Batch id 132, Training Loss = 3.873084306716919
# Batch id 133, Training Loss = 3.8749568462371826
# Batch id 134, Training Loss = 3.8762385845184326
# Batch id 135, Training Loss = 3.875936269760132
# Batch id 136, Training Loss = 3.874934196472168
# Batch id 137, Training Loss = 3.8764328956604004
# Batch id 138, Training Loss = 3.876112222671509
# Batch id 139, Training Loss = 3.874241828918457
# Batch id 140, Training Loss = 3.874631881713867
# Batch id 141, Training Loss = 3.875821113586426
# Batch id 142, Training Loss = 3.875699520111084
# Batch id 143, Training Loss = 3.8754332065582275
# Batch id 144, Training Loss = 3.876567840576172
# Batch id 145, Training Loss = 3.8745718002319336
# Batch id 146, Training Loss = 3.8760688304901123
# Batch id 147, Training Loss = 3.878675937652588
# Batch id 148, Training Loss = 3.877889633178711
# Batch id 149, Training Loss = 3.8757073879241943
# Batch id 150, Training Loss = 3.8756089210510254
# Batch id 151, Training Loss = 3.8754475116729736
# Batch id 152, Training Loss = 3.8766884803771973
# Batch id 153, Training Loss = 3.877638578414917
# Batch id 154, Training Loss = 3.879631280899048
# Batch id 155, Training Loss = 3.8801116943359375
# Batch id 156, Training Loss = 3.880429983139038
# Batch id 157, Training Loss = 3.8807597160339355
# Batch id 158, Training Loss = 3.8816773891448975
# Batch id 159, Training Loss = 3.882068157196045
# Batch id 160, Training Loss = 3.8827927112579346
# Batch id 161, Training Loss = 3.8837320804595947
# Batch id 162, Training Loss = 3.8829853534698486
# Batch id 163, Training Loss = 3.8835864067077637
# Batch id 164, Training Loss = 3.8827202320098877
# Batch id 165, Training Loss = 3.8844168186187744
# Batch id 166, Training Loss = 3.885920524597168
# Batch id 167, Training Loss = 3.885101556777954
# Batch id 168, Training Loss = 3.8852927684783936
# Batch id 169, Training Loss = 3.8846588134765625
# Batch id 170, Training Loss = 3.884730339050293
# Batch id 171, Training Loss = 3.885432243347168
# Batch id 172, Training Loss = 3.8864684104919434
# Batch id 173, Training Loss = 3.8853914737701416
# Batch id 174, Training Loss = 3.8840560913085938
# Batch id 175, Training Loss = 3.8829495906829834
# Batch id 176, Training Loss = 3.88592791557312
# Batch id 177, Training Loss = 3.8863561153411865
# Batch id 178, Training Loss = 3.885549545288086
# Batch id 179, Training Loss = 3.8843202590942383
# Batch id 180, Training Loss = 3.8841969966888428
# Batch id 181, Training Loss = 3.884861469268799
# Batch id 182, Training Loss = 3.885781764984131
# Batch id 183, Training Loss = 3.884446144104004
# Batch id 184, Training Loss = 3.885246992111206
# Batch id 185, Training Loss = 3.8859293460845947
# Batch id 186, Training Loss = 3.887545347213745
# Batch id 187, Training Loss = 3.888188600540161
# Batch id 188, Training Loss = 3.8888535499572754
# Batch id 189, Training Loss = 3.8908610343933105
# Batch id 190, Training Loss = 3.8899827003479004
# Batch id 191, Training Loss = 3.891017198562622
# Batch id 192, Training Loss = 3.8927900791168213
# Batch id 193, Training Loss = 3.8929781913757324
# Batch id 194, Training Loss = 3.8923139572143555
# Batch id 195, Training Loss = 3.892113447189331
# Batch id 196, Training Loss = 3.892439603805542
# Batch id 197, Training Loss = 3.8922152519226074
# Batch id 198, Training Loss = 3.8954994678497314
# Batch id 199, Training Loss = 3.8943324089050293
# Batch id 200, Training Loss = 3.8931779861450195
# Batch id 201, Training Loss = 3.8918237686157227
# Batch id 202, Training Loss = 3.892878532409668
# Batch id 203, Training Loss = 3.8936407566070557
# Batch id 204, Training Loss = 3.8931517601013184
# Batch id 205, Training Loss = 3.8940389156341553
# Batch id 206, Training Loss = 3.8956680297851562
# Batch id 207, Training Loss = 3.8960578441619873
# Batch id 208, Training Loss = 3.8951973915100098
# Finished epoch: 1 	Training Loss: 3.895197 	Validation Loss: 3.580715
# Validation loss decreased (inf --> 3.580715).  Saving model ...
# Batch id 0, Training Loss = 3.350015163421631
# Batch id 1, Training Loss = 3.3088648319244385
# Batch id 2, Training Loss = 3.4755501747131348
# Batch id 3, Training Loss = 3.5628020763397217
# Batch id 4, Training Loss = 3.4968388080596924
# Batch id 5, Training Loss = 3.5127806663513184
# Batch id 6, Training Loss = 3.4726011753082275
# Batch id 7, Training Loss = 3.4752719402313232
# Batch id 8, Training Loss = 3.4389336109161377
# Batch id 9, Training Loss = 3.438044786453247
# Batch id 10, Training Loss = 3.4590015411376953
# Batch id 11, Training Loss = 3.458401679992676
# Batch id 12, Training Loss = 3.4755308628082275
# Batch id 13, Training Loss = 3.503786325454712
# Batch id 14, Training Loss = 3.510937213897705
# Batch id 15, Training Loss = 3.5202176570892334
# Batch id 16, Training Loss = 3.517808198928833
# Batch id 17, Training Loss = 3.503960371017456
# Batch id 18, Training Loss = 3.5025439262390137
# Batch id 19, Training Loss = 3.4857535362243652
# Batch id 20, Training Loss = 3.48045015335083
# Batch id 21, Training Loss = 3.4795873165130615
# Batch id 22, Training Loss = 3.501086473464966
# Batch id 23, Training Loss = 3.505337953567505
# Batch id 24, Training Loss = 3.50038743019104
# Batch id 25, Training Loss = 3.4991719722747803
# Batch id 26, Training Loss = 3.503232002258301
# Batch id 27, Training Loss = 3.528118133544922
# Batch id 28, Training Loss = 3.53017520904541
# Batch id 29, Training Loss = 3.5347330570220947
# Batch id 30, Training Loss = 3.542905807495117
# Batch id 31, Training Loss = 3.541832685470581
# Batch id 32, Training Loss = 3.5395102500915527
# Batch id 33, Training Loss = 3.5346055030822754
# Batch id 34, Training Loss = 3.5425639152526855
# Batch id 35, Training Loss = 3.548513650894165
# Batch id 36, Training Loss = 3.5544450283050537
# Batch id 37, Training Loss = 3.5519487857818604
# Batch id 38, Training Loss = 3.559506416320801
# Batch id 39, Training Loss = 3.5637307167053223
# Batch id 40, Training Loss = 3.5747499465942383
# Batch id 41, Training Loss = 3.575181484222412
# Batch id 42, Training Loss = 3.5759387016296387
# Batch id 43, Training Loss = 3.5706725120544434
# Batch id 44, Training Loss = 3.56630539894104
# Batch id 45, Training Loss = 3.56758451461792
# Batch id 46, Training Loss = 3.5581626892089844
# Batch id 47, Training Loss = 3.5601561069488525
# Batch id 48, Training Loss = 3.5565617084503174
# Batch id 49, Training Loss = 3.5588138103485107
# Batch id 50, Training Loss = 3.5562686920166016
# Batch id 51, Training Loss = 3.5600500106811523
# Batch id 52, Training Loss = 3.5677216053009033
# Batch id 53, Training Loss = 3.5606560707092285
# Batch id 54, Training Loss = 3.566702127456665
# Batch id 55, Training Loss = 3.566138982772827
# Batch id 56, Training Loss = 3.5651628971099854
# Batch id 57, Training Loss = 3.5700979232788086
# Batch id 58, Training Loss = 3.5807783603668213
# Batch id 59, Training Loss = 3.5765652656555176
# Batch id 60, Training Loss = 3.580204725265503
# Batch id 61, Training Loss = 3.5847442150115967
# Batch id 62, Training Loss = 3.580065965652466
# Batch id 63, Training Loss = 3.5816116333007812
# Batch id 64, Training Loss = 3.5827226638793945
# Batch id 65, Training Loss = 3.581055164337158
# Batch id 66, Training Loss = 3.577840805053711
# Batch id 67, Training Loss = 3.576211929321289
# Batch id 68, Training Loss = 3.5760488510131836
# Batch id 69, Training Loss = 3.579073905944824
# Batch id 70, Training Loss = 3.581801176071167
# Batch id 71, Training Loss = 3.581947088241577
# Batch id 72, Training Loss = 3.5890960693359375
# Batch id 73, Training Loss = 3.5926513671875
# Batch id 74, Training Loss = 3.592849016189575
# Batch id 75, Training Loss = 3.5925955772399902
# Batch id 76, Training Loss = 3.595118284225464
# Batch id 77, Training Loss = 3.5919454097747803
# Batch id 78, Training Loss = 3.5905354022979736
# Batch id 79, Training Loss = 3.586198091506958
# Batch id 80, Training Loss = 3.5897104740142822
# Batch id 81, Training Loss = 3.58829402923584
# Batch id 82, Training Loss = 3.5851759910583496
# Batch id 83, Training Loss = 3.5880110263824463
# Batch id 84, Training Loss = 3.5888423919677734
# Batch id 85, Training Loss = 3.5868401527404785
# Batch id 86, Training Loss = 3.5873568058013916
# Batch id 87, Training Loss = 3.586623430252075
# Batch id 88, Training Loss = 3.588216781616211
# Batch id 89, Training Loss = 3.59169602394104
# Batch id 90, Training Loss = 3.5933539867401123
# Batch id 91, Training Loss = 3.593810796737671
# Batch id 92, Training Loss = 3.598726511001587
# Batch id 93, Training Loss = 3.598698616027832
# Batch id 94, Training Loss = 3.6004254817962646
# Batch id 95, Training Loss = 3.6011364459991455
# Batch id 96, Training Loss = 3.6015045642852783
# Batch id 97, Training Loss = 3.601043462753296
# Batch id 98, Training Loss = 3.5973074436187744
# Batch id 99, Training Loss = 3.5985987186431885
# Batch id 100, Training Loss = 3.5984466075897217
# Batch id 101, Training Loss = 3.596397638320923
# Batch id 102, Training Loss = 3.5978891849517822
# Batch id 103, Training Loss = 3.595125198364258
# Batch id 104, Training Loss = 3.5969948768615723
# Batch id 105, Training Loss = 3.5986201763153076
# Batch id 106, Training Loss = 3.601640462875366
# Batch id 107, Training Loss = 3.6033005714416504
# Batch id 108, Training Loss = 3.604701042175293
# Batch id 109, Training Loss = 3.60426664352417
# Batch id 110, Training Loss = 3.6049907207489014
# Batch id 111, Training Loss = 3.605093002319336
# Batch id 112, Training Loss = 3.6056435108184814
# Batch id 113, Training Loss = 3.6059377193450928
# Batch id 114, Training Loss = 3.605659246444702
# Batch id 115, Training Loss = 3.6035513877868652
# Batch id 116, Training Loss = 3.6061489582061768
# Batch id 117, Training Loss = 3.6054792404174805
# Batch id 118, Training Loss = 3.6013166904449463
# Batch id 119, Training Loss = 3.599680185317993
# Batch id 120, Training Loss = 3.598325729370117
# Batch id 121, Training Loss = 3.5982348918914795
# Batch id 122, Training Loss = 3.599419116973877
# Batch id 123, Training Loss = 3.6010050773620605
# Batch id 124, Training Loss = 3.600748062133789
# Batch id 125, Training Loss = 3.600388526916504
# Batch id 126, Training Loss = 3.6015982627868652
# Batch id 127, Training Loss = 3.601439952850342
# Batch id 128, Training Loss = 3.604067087173462
# Batch id 129, Training Loss = 3.607008218765259
# Batch id 130, Training Loss = 3.6075475215911865
# Batch id 131, Training Loss = 3.6067309379577637
# Batch id 132, Training Loss = 3.6056156158447266
# Batch id 133, Training Loss = 3.607672691345215
# Batch id 134, Training Loss = 3.6073572635650635
# Batch id 135, Training Loss = 3.6081178188323975
# Batch id 136, Training Loss = 3.6092677116394043
# Batch id 137, Training Loss = 3.609238624572754
# Batch id 138, Training Loss = 3.610060930252075
# Batch id 139, Training Loss = 3.608907461166382
# Batch id 140, Training Loss = 3.608447790145874
# Batch id 141, Training Loss = 3.6115403175354004
# Batch id 142, Training Loss = 3.6087069511413574
# Batch id 143, Training Loss = 3.608863115310669
# Batch id 144, Training Loss = 3.6089162826538086
# Batch id 145, Training Loss = 3.608804941177368
# Batch id 146, Training Loss = 3.6088640689849854
# Batch id 147, Training Loss = 3.6116392612457275
# Batch id 148, Training Loss = 3.611804962158203
# Batch id 149, Training Loss = 3.6133320331573486
# Batch id 150, Training Loss = 3.612156391143799
# Batch id 151, Training Loss = 3.612273931503296
# Batch id 152, Training Loss = 3.6152892112731934
# Batch id 153, Training Loss = 3.6158626079559326
# Batch id 154, Training Loss = 3.6163859367370605
# Batch id 155, Training Loss = 3.619422197341919
# Batch id 156, Training Loss = 3.6205241680145264
# Batch id 157, Training Loss = 3.620126724243164
# Batch id 158, Training Loss = 3.6192824840545654
# Batch id 159, Training Loss = 3.6219992637634277
# Batch id 160, Training Loss = 3.6197147369384766
# Batch id 161, Training Loss = 3.6214728355407715
# Batch id 162, Training Loss = 3.6211488246917725
# Batch id 163, Training Loss = 3.620414972305298
# Batch id 164, Training Loss = 3.6193583011627197
# Batch id 165, Training Loss = 3.619462490081787
# Batch id 166, Training Loss = 3.6184051036834717
# Batch id 167, Training Loss = 3.617671251296997
# Batch id 168, Training Loss = 3.617398262023926
# Batch id 169, Training Loss = 3.619067668914795
# Batch id 170, Training Loss = 3.6189324855804443
# Batch id 171, Training Loss = 3.620652437210083
# Batch id 172, Training Loss = 3.6209731101989746
# Batch id 173, Training Loss = 3.6202986240386963
# Batch id 174, Training Loss = 3.623781204223633
# Batch id 175, Training Loss = 3.6227807998657227
# Batch id 176, Training Loss = 3.6228888034820557
# Batch id 177, Training Loss = 3.623427629470825
# Batch id 178, Training Loss = 3.622469425201416
# Batch id 179, Training Loss = 3.624656915664673
# Batch id 180, Training Loss = 3.623528480529785
# Batch id 181, Training Loss = 3.6241021156311035
# Batch id 182, Training Loss = 3.623532295227051
# Batch id 183, Training Loss = 3.6227123737335205
# Batch id 184, Training Loss = 3.623508930206299
# Batch id 185, Training Loss = 3.6253931522369385
# Batch id 186, Training Loss = 3.6244208812713623
# Batch id 187, Training Loss = 3.623788833618164
# Batch id 188, Training Loss = 3.622424602508545
# Batch id 189, Training Loss = 3.620460271835327
# Batch id 190, Training Loss = 3.6179773807525635
# Batch id 191, Training Loss = 3.6191513538360596
# Batch id 192, Training Loss = 3.620803117752075
# Batch id 193, Training Loss = 3.6224303245544434
# Batch id 194, Training Loss = 3.6216213703155518
# Batch id 195, Training Loss = 3.623446464538574
# Batch id 196, Training Loss = 3.624403953552246
# Batch id 197, Training Loss = 3.6248457431793213
# Batch id 198, Training Loss = 3.6260082721710205
# Batch id 199, Training Loss = 3.6261789798736572
# Batch id 200, Training Loss = 3.6273140907287598
# Batch id 201, Training Loss = 3.6255881786346436
# Batch id 202, Training Loss = 3.627535581588745
# Batch id 203, Training Loss = 3.6278560161590576
# Batch id 204, Training Loss = 3.6281368732452393
# Batch id 205, Training Loss = 3.626566171646118
# Batch id 206, Training Loss = 3.628023386001587
# Batch id 207, Training Loss = 3.629690408706665
# Batch id 208, Training Loss = 3.629744529724121
# Finished epoch: 2 	Training Loss: 3.629745 	Validation Loss: 3.263652
# Validation loss decreased (3.580715 --> 3.263652).  Saving model ...
# Batch id 0, Training Loss = 3.433901071548462
# Batch id 1, Training Loss = 3.392388343811035
# Batch id 2, Training Loss = 3.3177313804626465
# Batch id 3, Training Loss = 3.29856276512146
# Batch id 4, Training Loss = 3.3447721004486084
# Batch id 5, Training Loss = 3.317549705505371
# Batch id 6, Training Loss = 3.2707364559173584
# Batch id 7, Training Loss = 3.3006038665771484
# Batch id 8, Training Loss = 3.313311815261841
# Batch id 9, Training Loss = 3.322280168533325
# Batch id 10, Training Loss = 3.3434722423553467
# Batch id 11, Training Loss = 3.3270156383514404
# Batch id 12, Training Loss = 3.2885286808013916
# Batch id 13, Training Loss = 3.262759208679199
# Batch id 14, Training Loss = 3.2545716762542725
# Batch id 15, Training Loss = 3.2777340412139893
# Batch id 16, Training Loss = 3.261701822280884
# Batch id 17, Training Loss = 3.2515437602996826
# Batch id 18, Training Loss = 3.256591320037842
# Batch id 19, Training Loss = 3.2537028789520264
# Batch id 20, Training Loss = 3.245278835296631
# Batch id 21, Training Loss = 3.247425079345703
# Batch id 22, Training Loss = 3.2436697483062744
# Batch id 23, Training Loss = 3.2479259967803955
# Batch id 24, Training Loss = 3.2572550773620605
# Batch id 25, Training Loss = 3.268428325653076
# Batch id 26, Training Loss = 3.2781729698181152
# Batch id 27, Training Loss = 3.300856828689575
# Batch id 28, Training Loss = 3.296178102493286
# Batch id 29, Training Loss = 3.291325569152832
# Batch id 30, Training Loss = 3.283480644226074
# Batch id 31, Training Loss = 3.2854080200195312
# Batch id 32, Training Loss = 3.2931108474731445
# Batch id 33, Training Loss = 3.289106845855713
# Batch id 34, Training Loss = 3.288309335708618
# Batch id 35, Training Loss = 3.284552574157715
# Batch id 36, Training Loss = 3.304558753967285
# Batch id 37, Training Loss = 3.298874855041504
# Batch id 38, Training Loss = 3.314363479614258
# Batch id 39, Training Loss = 3.3123908042907715
# Batch id 40, Training Loss = 3.306084394454956
# Batch id 41, Training Loss = 3.301143169403076
# Batch id 42, Training Loss = 3.3003158569335938
# Batch id 43, Training Loss = 3.3000056743621826
# Batch id 44, Training Loss = 3.3013477325439453
# Batch id 45, Training Loss = 3.305476188659668
# Batch id 46, Training Loss = 3.3084630966186523
# Batch id 47, Training Loss = 3.303384780883789
# Batch id 48, Training Loss = 3.302626609802246
# Batch id 49, Training Loss = 3.302381992340088
# Batch id 50, Training Loss = 3.29648494720459
# Batch id 51, Training Loss = 3.2912890911102295
# Batch id 52, Training Loss = 3.285132646560669
# Batch id 53, Training Loss = 3.2853453159332275
# Batch id 54, Training Loss = 3.29025936126709
# Batch id 55, Training Loss = 3.2808988094329834
# Batch id 56, Training Loss = 3.2835419178009033
# Batch id 57, Training Loss = 3.2902259826660156
# Batch id 58, Training Loss = 3.2924444675445557
# Batch id 59, Training Loss = 3.288788080215454
# Batch id 60, Training Loss = 3.289609909057617
# Batch id 61, Training Loss = 3.285508632659912
# Batch id 62, Training Loss = 3.2886157035827637
# Batch id 63, Training Loss = 3.2923743724823
# Batch id 64, Training Loss = 3.300787925720215
# Batch id 65, Training Loss = 3.302039623260498
# Batch id 66, Training Loss = 3.303603172302246
# Batch id 67, Training Loss = 3.2970168590545654
# Batch id 68, Training Loss = 3.295862913131714
# Batch id 69, Training Loss = 3.2945098876953125
# Batch id 70, Training Loss = 3.2905831336975098
# Batch id 71, Training Loss = 3.289583921432495
# Batch id 72, Training Loss = 3.2893810272216797
# Batch id 73, Training Loss = 3.2883896827697754
# Batch id 74, Training Loss = 3.2894318103790283
# Batch id 75, Training Loss = 3.290149450302124
# Batch id 76, Training Loss = 3.2939934730529785
# Batch id 77, Training Loss = 3.294555425643921
# Batch id 78, Training Loss = 3.288503885269165
# Batch id 79, Training Loss = 3.289349317550659
# Batch id 80, Training Loss = 3.2892708778381348
# Batch id 81, Training Loss = 3.288022756576538
# Batch id 82, Training Loss = 3.290308713912964
# Batch id 83, Training Loss = 3.287555456161499
# Batch id 84, Training Loss = 3.290776014328003
# Batch id 85, Training Loss = 3.2923989295959473
# Batch id 86, Training Loss = 3.2912814617156982
# Batch id 87, Training Loss = 3.2924399375915527
# Batch id 88, Training Loss = 3.2947912216186523
# Batch id 89, Training Loss = 3.2965919971466064
# Batch id 90, Training Loss = 3.29073429107666
# Batch id 91, Training Loss = 3.294029474258423
# Batch id 92, Training Loss = 3.2964887619018555
# Batch id 93, Training Loss = 3.29645037651062
# Batch id 94, Training Loss = 3.2951912879943848
# Batch id 95, Training Loss = 3.299772024154663
# Batch id 96, Training Loss = 3.3011159896850586
# Batch id 97, Training Loss = 3.3041305541992188
# Batch id 98, Training Loss = 3.3036270141601562
# Batch id 99, Training Loss = 3.3091330528259277
# Batch id 100, Training Loss = 3.3111109733581543
# Batch id 101, Training Loss = 3.3113179206848145
# Batch id 102, Training Loss = 3.3077549934387207
# Batch id 103, Training Loss = 3.310645818710327
# Batch id 104, Training Loss = 3.3112058639526367
# Batch id 105, Training Loss = 3.3133091926574707
# Batch id 106, Training Loss = 3.316986083984375
# Batch id 107, Training Loss = 3.3193483352661133
# Batch id 108, Training Loss = 3.3178155422210693
# Batch id 109, Training Loss = 3.3125369548797607
# Batch id 110, Training Loss = 3.31235671043396
# Batch id 111, Training Loss = 3.3123281002044678
# Batch id 112, Training Loss = 3.311478614807129
# Batch id 113, Training Loss = 3.315680742263794
# Batch id 114, Training Loss = 3.317686080932617
# Batch id 115, Training Loss = 3.318131685256958
# Batch id 116, Training Loss = 3.3179452419281006
# Batch id 117, Training Loss = 3.317500591278076
# Batch id 118, Training Loss = 3.317636013031006
# Batch id 119, Training Loss = 3.3192429542541504
# Batch id 120, Training Loss = 3.315621852874756
# Batch id 121, Training Loss = 3.31630277633667
# Batch id 122, Training Loss = 3.3152194023132324
# Batch id 123, Training Loss = 3.3186047077178955
# Batch id 124, Training Loss = 3.3198108673095703
# Batch id 125, Training Loss = 3.320521593093872
# Batch id 126, Training Loss = 3.3186864852905273
# Batch id 127, Training Loss = 3.319641351699829
# Batch id 128, Training Loss = 3.3186938762664795
# Batch id 129, Training Loss = 3.318268299102783
# Batch id 130, Training Loss = 3.3183023929595947
# Batch id 131, Training Loss = 3.3202033042907715
# Batch id 132, Training Loss = 3.320197582244873
# Batch id 133, Training Loss = 3.3190696239471436
# Batch id 134, Training Loss = 3.3189473152160645
# Batch id 135, Training Loss = 3.321530342102051
# Batch id 136, Training Loss = 3.3226802349090576
# Batch id 137, Training Loss = 3.324007034301758
# Batch id 138, Training Loss = 3.326807737350464
# Batch id 139, Training Loss = 3.3256592750549316
# Batch id 140, Training Loss = 3.324312210083008
# Batch id 141, Training Loss = 3.3220555782318115
# Batch id 142, Training Loss = 3.3250749111175537
# Batch id 143, Training Loss = 3.326645851135254
# Batch id 144, Training Loss = 3.327308177947998
# Batch id 145, Training Loss = 3.3283348083496094
# Batch id 146, Training Loss = 3.3309333324432373
# Batch id 147, Training Loss = 3.3311569690704346
# Batch id 148, Training Loss = 3.3331046104431152
# Batch id 149, Training Loss = 3.329871892929077
# Batch id 150, Training Loss = 3.3310296535491943
# Batch id 151, Training Loss = 3.3302061557769775
# Batch id 152, Training Loss = 3.329078435897827
# Batch id 153, Training Loss = 3.3323452472686768
# Batch id 154, Training Loss = 3.3332602977752686
# Batch id 155, Training Loss = 3.3310630321502686
# Batch id 156, Training Loss = 3.3330607414245605
# Batch id 157, Training Loss = 3.332226037979126
# Batch id 158, Training Loss = 3.3314828872680664
# Batch id 159, Training Loss = 3.3353846073150635
# Batch id 160, Training Loss = 3.334498882293701
# Batch id 161, Training Loss = 3.3342227935791016
# Batch id 162, Training Loss = 3.3358047008514404
# Batch id 163, Training Loss = 3.3357512950897217
# Batch id 164, Training Loss = 3.3368613719940186
# Batch id 165, Training Loss = 3.337664842605591
# Batch id 166, Training Loss = 3.3375017642974854
# Batch id 167, Training Loss = 3.3382515907287598
# Batch id 168, Training Loss = 3.3397786617279053
# Batch id 169, Training Loss = 3.3400704860687256
# Batch id 170, Training Loss = 3.341858386993408
# Batch id 171, Training Loss = 3.3419816493988037
# Batch id 172, Training Loss = 3.3406596183776855
# Batch id 173, Training Loss = 3.33945894241333
# Batch id 174, Training Loss = 3.338568925857544
# Batch id 175, Training Loss = 3.337415933609009
# Batch id 176, Training Loss = 3.337948799133301
# Batch id 177, Training Loss = 3.3375847339630127
# Batch id 178, Training Loss = 3.337013006210327
# Batch id 179, Training Loss = 3.3392581939697266
# Batch id 180, Training Loss = 3.3374931812286377
# Batch id 181, Training Loss = 3.335888147354126
# Batch id 182, Training Loss = 3.3361659049987793
# Batch id 183, Training Loss = 3.33708119392395
# Batch id 184, Training Loss = 3.3391218185424805
# Batch id 185, Training Loss = 3.3378429412841797
# Batch id 186, Training Loss = 3.3397316932678223
# Batch id 187, Training Loss = 3.338898181915283
# Batch id 188, Training Loss = 3.3387835025787354
# Batch id 189, Training Loss = 3.338984489440918
# Batch id 190, Training Loss = 3.3403568267822266
# Batch id 191, Training Loss = 3.3428280353546143
# Batch id 192, Training Loss = 3.3440775871276855
# Batch id 193, Training Loss = 3.343214511871338
# Batch id 194, Training Loss = 3.3451857566833496
# Batch id 195, Training Loss = 3.3428170680999756
# Batch id 196, Training Loss = 3.341521739959717
# Batch id 197, Training Loss = 3.341003179550171
# Batch id 198, Training Loss = 3.3404760360717773
# Batch id 199, Training Loss = 3.3407857418060303
# Batch id 200, Training Loss = 3.3424434661865234
# Batch id 201, Training Loss = 3.3430793285369873
# Batch id 202, Training Loss = 3.343309164047241
# Batch id 203, Training Loss = 3.3427557945251465
# Batch id 204, Training Loss = 3.3421895503997803
# Batch id 205, Training Loss = 3.3439035415649414
# Batch id 206, Training Loss = 3.3450677394866943
# Batch id 207, Training Loss = 3.3482935428619385
# Batch id 208, Training Loss = 3.348994731903076
# Finished epoch: 3 	Training Loss: 3.348995 	Validation Loss: 2.930927
# Validation loss decreased (3.263652 --> 2.930927).  Saving model ...

# %%
import copy
import os
import torch
import tqdm
from torch.optim.lr_scheduler import _LRScheduler
import matplotlib.pyplot as plt


class LRFinder(object):
    """Learning rate range test.
    The learning rate range test increases the learning rate in a pre-training run
    between two boundaries in a linear or exponential manner. It provides valuable
    information on how well the network can be trained over a range of learning rates
    and what is the optimal learning rate.
    Arguments:
        model (torch.nn.Module): wrapped model.
        optimizer (torch.optim.Optimizer): wrapped optimizer where the defined learning
            is assumed to be the lower boundary of the range test.
        criterion (torch.nn.Module): wrapped loss function.
        device (str or torch.device, optional): a string ("cpu" or "cuda") with an
            optional ordinal for the device type (e.g. "cuda:X", where is the ordinal).
            Alternatively, can be an object representing the device on which the
            computation will take place. Default: None, uses the same device as `model`.
        memory_cache (boolean): if this flag is set to True, `state_dict` of model and
            optimizer will be cached in memory. Otherwise, they will be saved to files
            under the `cache_dir`.
        cache_dir (string): path for storing temporary files. If no path is specified,
            system-wide temporary directory is used.
            Notice that this parameter will be ignored if `memory_cache` is True.
    Example:
        >>> lr_finder = LRFinder(net, optimizer, criterion, device="cuda")
        >>> lr_finder.range_test(dataloader, end_lr=100, num_iter=100)
    Cyclical Learning Rates for Training Neural Networks: https://arxiv.org/abs/1506.01186
    fastai/lr_find: https://github.com/fastai/fastai
    """

    def __init__(self, model, optimizer, criterion, device=None, memory_cache=True, cache_dir=None):
        self.model = model
        self.optimizer = optimizer
        self.criterion = criterion
        self.history = {"lr": [], "loss": []}
        self.best_loss = None
        self.memory_cache = memory_cache
        self.cache_dir = cache_dir

        # Save the original state of the model and optimizer so they can be restored if
        # needed
        self.model_device = next(self.model.parameters()).device
        self.state_cacher = StateCacher(memory_cache, cache_dir=cache_dir)
        self.state_cacher.store('model', self.model.state_dict())
        self.state_cacher.store('optimizer', self.optimizer.state_dict())

        # If device is None, use the same as the model
        if device:
            self.device = device
        else:
            self.device = self.model_device

    def reset(self):
        """Restores the model and optimizer to their initial states."""
        self.model.load_state_dict(self.state_cacher.retrieve('model'))
        self.optimizer.load_state_dict(self.state_cacher.retrieve('optimizer'))
        self.model.to(self.model_device)

    def range_test(
        self,
        train_loader,
        val_loader=None,
        end_lr=10,
        num_iter=100,
        step_mode="exp",
        smooth_f=0.05,
        diverge_th=5,
    ):
        """Performs the learning rate range test.
        Arguments:
            train_loader (torch.utils.data.DataLoader): the training set data laoder.
            val_loader (torch.utils.data.DataLoader, optional): if `None` the range test
                will only use the training loss. When given a data loader, the model is
                evaluated after each iteration on that dataset and the evaluation loss
                is used. Note that in this mode the test takes significantly longer but
                generally produces more precise results. Default: None.
            end_lr (float, optional): the maximum learning rate to test. Default: 10.
            num_iter (int, optional): the number of iterations over which the test
                occurs. Default: 100.
            step_mode (str, optional): one of the available learning rate policies,
                linear or exponential ("linear", "exp"). Default: "exp".
            smooth_f (float, optional): the loss smoothing factor within the [0, 1[
                interval. Disabled if set to 0, otherwise the loss is smoothed using
                exponential smoothing. Default: 0.05.
            diverge_th (int, optional): the test is stopped when the loss surpasses the
                threshold:  diverge_th * best_loss. Default: 5.
        """
        # Reset test results
        self.history = {"lr": [], "loss": []}
        self.best_loss = None

        # Move the model to the proper device
        self.model.to(self.device)

        # Initialize the proper learning rate policy
        if step_mode.lower() == "exp":
            lr_schedule = ExponentialLR(self.optimizer, end_lr, num_iter)
        elif step_mode.lower() == "linear":
            lr_schedule = LinearLR(self.optimizer, end_lr, num_iter)
        else:
            raise ValueError("expected one of (exp, linear), got {}".format(step_mode))

        if smooth_f < 0 or smooth_f >= 1:
            raise ValueError("smooth_f is outside the range [0, 1[")

        # Create an iterator to get data batch by batch
        iterator = iter(train_loader)
        for iteration in range(num_iter):
            # Get a new set of inputs and labels
            try:
                inputs, labels = next(iterator)
            except StopIteration:
                iterator = iter(train_loader)
                inputs, labels = next(iterator)

            # Train on batch and retrieve loss
            loss = self._train_batch(inputs, labels)
            if val_loader:
                loss = self._validate(val_loader)

            # Update the learning rate
            lr_schedule.step()
            self.history["lr"].append(lr_schedule.get_lr()[0])

            # Track the best loss and smooth it if smooth_f is specified
            if iteration == 0:
                self.best_loss = loss
            else:
                if smooth_f > 0:
                    loss = smooth_f * loss + (1 - smooth_f) * self.history["loss"][-1]
                if loss < self.best_loss:
                    self.best_loss = loss

            # Check if the loss has diverged; if it has, stop the test
            self.history["loss"].append(loss)
            if loss > diverge_th * self.best_loss:
                print("Stopping early, the loss has diverged")
                break

        print("Learning rate search finished. See the graph with {finder_name}.plot()")

    def _train_batch(self, inputs, labels):
        # Set model to training mode
        self.model.train()

        # Move data to the correct device
        inputs = inputs.to(self.device)
        labels = labels.to(self.device)

        # Forward pass
        self.optimizer.zero_grad()
        outputs = self.model(inputs)
        loss = self.criterion(outputs, labels)

        # Backward pass
        loss.backward()
        self.optimizer.step()

        return loss.item()

    def _validate(self, dataloader):
        # Set model to evaluation mode and disable gradient computation
        running_loss = 0
        self.model.eval()
        with torch.no_grad():
            for inputs, labels in dataloader:
                # Move data to the correct device
                inputs = inputs.to(self.device)
                labels = labels.to(self.device)

                # Forward pass and loss computation
                outputs = self.model(inputs)
                loss = self.criterion(outputs, labels)
                running_loss += loss.item() * inputs.size(0)

        return running_loss / len(dataloader.dataset)

    def plot(self, skip_start=10, skip_end=5, log_lr=True):
        """Plots the learning rate range test.
        Arguments:
            skip_start (int, optional): number of batches to trim from the start.
                Default: 10.
            skip_end (int, optional): number of batches to trim from the start.
                Default: 5.
            log_lr (bool, optional): True to plot the learning rate in a logarithmic
                scale; otherwise, plotted in a linear scale. Default: True.
        """

        if skip_start < 0:
            raise ValueError("skip_start cannot be negative")
        if skip_end < 0:
            raise ValueError("skip_end cannot be negative")

        # Get the data to plot from the history dictionary. Also, handle skip_end=0
        # properly so the behaviour is the expected
        lrs = self.history["lr"]
        losses = self.history["loss"]
        if skip_end == 0:
            lrs = lrs[skip_start:]
            losses = losses[skip_start:]
        else:
            lrs = lrs[skip_start:-skip_end]
            losses = losses[skip_start:-skip_end]

        # Plot loss as a function of the learning rate
        plt.plot(lrs, losses)
        if log_lr:
            plt.xscale("log")
        plt.xlabel("Learning rate")
        plt.ylabel("Loss")
        plt.show()


class LinearLR(_LRScheduler):
    """Linearly increases the learning rate between two boundaries over a number of
    iterations.
    Arguments:
        optimizer (torch.optim.Optimizer): wrapped optimizer.
        end_lr (float, optional): the initial learning rate which is the lower
            boundary of the test. Default: 10.
        num_iter (int, optional): the number of iterations over which the test
            occurs. Default: 100.
        last_epoch (int): the index of last epoch. Default: -1.
    """

    def __init__(self, optimizer, end_lr, num_iter, last_epoch=-1):
        self.end_lr = end_lr
        self.num_iter = num_iter
        super(LinearLR, self).__init__(optimizer, last_epoch)

    def get_lr(self):
        curr_iter = self.last_epoch + 1
        r = curr_iter / self.num_iter
        return [base_lr + r * (self.end_lr - base_lr) for base_lr in self.base_lrs]


class ExponentialLR(_LRScheduler):
    """Exponentially increases the learning rate between two boundaries over a number of
    iterations.
    Arguments:
        optimizer (torch.optim.Optimizer): wrapped optimizer.
        end_lr (float, optional): the initial learning rate which is the lower
            boundary of the test. Default: 10.
        num_iter (int, optional): the number of iterations over which the test
            occurs. Default: 100.
        last_epoch (int): the index of last epoch. Default: -1.
    """

    def __init__(self, optimizer, end_lr, num_iter, last_epoch=-1):
        self.end_lr = end_lr
        self.num_iter = num_iter
        super(ExponentialLR, self).__init__(optimizer, last_epoch)

    def get_lr(self):
        curr_iter = self.last_epoch + 1
        r = curr_iter / self.num_iter
        return [base_lr * (self.end_lr / base_lr) ** r for base_lr in self.base_lrs]


class StateCacher(object):
    def __init__(self, in_memory, cache_dir=None):
        self.in_memory = in_memory
        self.cache_dir = cache_dir

        if self.cache_dir is None:
            import tempfile
            self.cache_dir = tempfile.gettempdir()
        else:
            if not os.path.isdir(self.cache_dir):
                raise ValueError('Given `cache_dir` is not a valid directory.')

        self.cached = {}

    def store(self, key, state_dict):
        if self.in_memory:
            self.cached.update({key: copy.deepcopy(state_dict)})
        else:
            fn = os.path.join(self.cache_dir, 'state_{}_{}.pt'.format(key, id(self)))
            self.cached.update({key: fn})
            torch.save(state_dict, fn)

    def retrieve(self, key):
        if key not in self.cached:
            raise KeyError('Target {} was not cached.'.format(key))

        if self.in_memory:
            return self.cached.get(key)
        else:
            fn = self.cached.get(key)
            if not os.path.exists(fn):
                raise RuntimeError('Failed to load state in {}. File does not exist anymore.'.format(fn))
            state_dict = torch.load(fn, map_location=lambda storage, location: storage)
            return state_dict

    def __del__(self):
        """Check whether there are unused cached files existing in `cache_dir` before
        this instance being destroyed."""
        if self.in_memory:
            return

        for k in self.cached:
            if os.path.exists(self.cached[k]):
                os.remove(self.cached[k])

# %%
lr_finder = LRFinder(model_scratch, optimizer_scratch, criterion_scratch, device="cuda")
lr_finder.range_test(loaders['train'], end_lr=10, num_iter=100)
lr_finder.plot()
# Out:
# Stopping early, the loss has diverged
# Learning rate search finished. See the graph with {finder_name}.plot()

# %% [markdown]
# ### Attempts (after 3 epochs)
# - Tried one conv, 5x5, maxpool 2x2 and one fc
#     - 9% accuracy
# - Tried adding one new fc
#     - Memory error
# - Increased stride to 2
#     - Weird lr finder
#     - 13% accuracy
#     - Trained for more 3 epochs
#         - Test accuracy of 35%

# %% [markdown]
# ### (IMPLEMENTATION) Test the Model
#
# Try out your model on the test dataset of dog images.  Use the code cell below to calculate and print the test loss and accuracy.  Ensure that your test accuracy is greater than 10%.

# %%
def test(loaders, model, criterion, use_cuda):

    # monitor test loss and accuracy
    test_loss = 0.
    correct = 0.
    total = 0.

    model.eval()
    with torch.no_grad():
        for batch_idx, (data, target) in enumerate(loaders['test']):
            # move to GPU
            if use_cuda:
                data, target = data.cuda(), target.cuda()
            # forward pass: compute predicted outputs by passing inputs to the model
            output = model(data)
            # calculate the loss
            loss = criterion(output, target)
            # update average test loss 
            test_loss = test_loss + ((1 / (batch_idx + 1)) * (loss.data - test_loss))
            # convert output probabilities to predicted class
            pred = output.data.max(1, keepdim=True)[1]
            # compare predictions to true label
            correct += np.sum(np.squeeze(pred.eq(target.data.view_as(pred))).cpu().numpy())
            total += data.size(0)

        print('Test Loss: {:.6f}\n'.format(test_loss))

        print('\nTest Accuracy: %2d%% (%2d/%2d)' % (
            100. * correct / total, correct, total))

# call test function    
test(loaders, model_scratch, criterion_scratch, use_cuda)
# Out:
# Test Loss: 2.930927
#
#
# Test Accuracy: 35% (2362/6680)

# %% [markdown]
# ---
# <a id='step4'></a>
# ## Step 4: Create a CNN to Classify Dog Breeds (using Transfer Learning)
#
# You will now use transfer learning to create a CNN that can identify dog breed from images.  Your CNN must attain at least 60% accuracy on the test set.
#
# ### (IMPLEMENTATION) Specify Data Loaders for the Dog Dataset
#
# Use the code cell below to write three separate [data loaders](http://pytorch.org/docs/master/data.html#torch.utils.data.DataLoader) for the training, validation, and test datasets of dog images (located at `dogImages/train`, `dogImages/valid`, and `dogImages/test`, respectively).
#
# If you like, **you are welcome to use the same data loaders from the previous step**, when you created a CNN from scratch.

# %%
## TODO: Specify data loaders
import os
from torchvision import datasets

### TODO: Write data loaders for training, validation, and test sets
## Specify appropriate transformimagenet_data = torchvision.datasets.ImageFolder('path/to/imagenet_root/')

BATCH_SIZE = 32
normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406],
                             std=[0.229, 0.224, 0.225])

transform = transforms.Compose([
    transforms.Resize(224),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    normalize])


train_set = datasets.ImageFolder("/data/dog_images/train", transform=transform)    

train_loader = torch.utils.data.DataLoader(train_set,
                                          batch_size=BATCH_SIZE,
                                          shuffle=True)

valid_set = datasets.ImageFolder("/data/dog_images/valid", transform=transform)    

valid_loader = torch.utils.data.DataLoader(train_set,
                                          batch_size=BATCH_SIZE)

test_set = datasets.ImageFolder("/data/dog_images/test", transform=transform)    

test_loader = torch.utils.data.DataLoader(train_set,
                                          batch_size=BATCH_SIZE)

loaders_transfer = {'train': train_loader, 'valid': valid_loader, 'test': test_loader}

# %% [markdown]
# ### (IMPLEMENTATION) Model Architecture
#
# Use transfer learning to create a CNN to classify dog breed.  Use the code cell below, and save your initialized model as the variable `model_transfer`.

# %%
import torchvision.models as models
import torch.nn as nn

## TODO: Specify model architecture 
# define VGG16 model
model_transfer = models.vgg16(pretrained=True)

# Freeze features parameters
for param in model_transfer.features.parameters():
    param.require_grad = False
    
n_inputs = model_transfer.classifier[6].in_features

last_layer = nn.Linear(n_inputs, 133)

model_transfer.classifier[6] = last_layer

if use_cuda:
    model_transfer = model_transfer.cuda()

# %% [markdown]
# __Question 5:__ Outline the steps you took to get to your final CNN architecture and your reasoning at each step.  Describe why you think the architecture is suitable for the current problem.

# %% [markdown]
# __Answer:__

# %% [markdown]
# ### (IMPLEMENTATION) Specify Loss Function and Optimizer
#
# Use the next code cell to specify a [loss function](http://pytorch.org/docs/master/nn.html#loss-functions) and [optimizer](http://pytorch.org/docs/master/optim.html).  Save the chosen loss function as `criterion_transfer`, and the optimizer as `optimizer_transfer` below.

# %%
criterion_transfer = nn.CrossEntropyLoss()
optimizer_transfer = optim.SGD(model_transfer.classifier.parameters(), lr=4e-2)

# %%
lr_finder = LRFinder(model_transfer, optimizer_transfer, criterion_transfer, device="cuda")
lr_finder.range_test(loaders_transfer['train'], end_lr=10, num_iter=100)
lr_finder.plot()
# Out:
# Stopping early, the loss has diverged
# Learning rate search finished. See the graph with {finder_name}.plot()

# %%
4e-2
# Out:
# 0.04

# %% [markdown]
# ### (IMPLEMENTATION) Train and Validate the Model
#
# Train and validate your model in the code cell below.  [Save the final model parameters](http://pytorch.org/docs/master/notes/serialization.html) at filepath `'model_transfer.pt'`.

# %%
# train the model
model_transfer = train(3, loaders_transfer, model_transfer, optimizer_transfer, criterion_transfer, use_cuda, 'model_transfer.pt', valid_loss_min=0.243631)

# load the model that got the best validation accuracy (uncomment the line below)
#model_transfer.load_state_dict(torch.load('model_transfer.pt'))
# Out:
# Batch id 0, Training Loss = 5.205445289611816
# Batch id 1, Training Loss = 4.919153213500977
# Batch id 2, Training Loss = 4.9645819664001465
# Batch id 3, Training Loss = 4.842308521270752
# Batch id 4, Training Loss = 4.748326778411865
# Batch id 5, Training Loss = 4.643002986907959
# Batch id 6, Training Loss = 4.569539546966553
# Batch id 7, Training Loss = 4.446266174316406
# Batch id 8, Training Loss = 4.38787841796875
# Batch id 9, Training Loss = 4.283642292022705
# Batch id 10, Training Loss = 4.220707893371582
# Batch id 11, Training Loss = 4.107441425323486
# Batch id 12, Training Loss = 4.0077667236328125
# Batch id 13, Training Loss = 3.9673149585723877
# Batch id 14, Training Loss = 3.9058377742767334
# Batch id 15, Training Loss = 3.8399388790130615
# Batch id 16, Training Loss = 3.7782349586486816
# Batch id 17, Training Loss = 3.7197768688201904
# Batch id 18, Training Loss = 3.6546645164489746
# Batch id 19, Training Loss = 3.605170726776123
# Batch id 20, Training Loss = 3.5479772090911865
# Batch id 21, Training Loss = 3.4933128356933594
# Batch id 22, Training Loss = 3.437270402908325
# Batch id 23, Training Loss = 3.3837172985076904
# Batch id 24, Training Loss = 3.3158059120178223
# Batch id 25, Training Loss = 3.2518322467803955
# Batch id 26, Training Loss = 3.183957099914551
# Batch id 27, Training Loss = 3.118480920791626
# Batch id 28, Training Loss = 3.0718657970428467
# Batch id 29, Training Loss = 3.0244734287261963
# Batch id 30, Training Loss = 3.000781774520874
# Batch id 31, Training Loss = 2.9695241451263428
# Batch id 32, Training Loss = 2.922382354736328
# Batch id 33, Training Loss = 2.883212089538574
# Batch id 34, Training Loss = 2.8549435138702393
# Batch id 35, Training Loss = 2.822310209274292
# Batch id 36, Training Loss = 2.7878692150115967
# Batch id 37, Training Loss = 2.7569375038146973
# Batch id 38, Training Loss = 2.721421718597412
# Batch id 39, Training Loss = 2.681600570678711
# Batch id 46, Training Loss = 2.495103359222412
# Batch id 47, Training Loss = 2.4668643474578857
# Batch id 48, Training Loss = 2.443117380142212
# Batch id 49, Training Loss = 2.417224645614624
# Batch id 50, Training Loss = 2.405064105987549
# Batch id 51, Training Loss = 2.383049726486206
# Batch id 52, Training Loss = 2.3608481884002686
# Batch id 53, Training Loss = 2.3377604484558105
# Batch id 54, Training Loss = 2.311912775039673
# Batch id 55, Training Loss = 2.287642002105713
# Batch id 56, Training Loss = 2.2677013874053955
# Batch id 57, Training Loss = 2.2542147636413574
# Batch id 58, Training Loss = 2.2419095039367676
# Batch id 59, Training Loss = 2.2287585735321045
# Batch id 60, Training Loss = 2.2166876792907715
# Batch id 61, Training Loss = 2.198488712310791
# Batch id 62, Training Loss = 2.194878101348877
# Batch id 63, Training Loss = 2.1808149814605713
# Batch id 64, Training Loss = 2.1642239093780518
# Batch id 65, Training Loss = 2.1499059200286865
# Batch id 66, Training Loss = 2.1440579891204834
# Batch id 67, Training Loss = 2.1388864517211914
# Batch id 68, Training Loss = 2.1229941844940186
# Batch id 69, Training Loss = 2.112325429916382
# Batch id 70, Training Loss = 2.1110682487487793
# Batch id 71, Training Loss = 2.1082592010498047
# Batch id 72, Training Loss = 2.093616485595703
# Batch id 73, Training Loss = 2.074063301086426
# Batch id 74, Training Loss = 2.061955690383911
# Batch id 75, Training Loss = 2.0532212257385254
# Batch id 76, Training Loss = 2.0509557723999023
# Batch id 77, Training Loss = 2.047173500061035
# Batch id 78, Training Loss = 2.03892183303833
# Batch id 79, Training Loss = 2.0320513248443604
# Batch id 80, Training Loss = 2.017970323562622
# Batch id 81, Training Loss = 2.0110552310943604
# Batch id 82, Training Loss = 2.0084354877471924
# Batch id 83, Training Loss = 1.9948759078979492
# Batch id 84, Training Loss = 1.9884443283081055
# Batch id 85, Training Loss = 1.9828834533691406
# Batch id 86, Training Loss = 1.975274920463562
# Batch id 87, Training Loss = 1.9664690494537354
# Batch id 88, Training Loss = 1.9609313011169434
# Batch id 89, Training Loss = 1.9571138620376587
# Batch id 90, Training Loss = 1.9461150169372559
# Batch id 91, Training Loss = 1.9374322891235352
# Batch id 92, Training Loss = 1.9344143867492676
# Batch id 93, Training Loss = 1.9203476905822754
# Batch id 94, Training Loss = 1.913448452949524
# Batch id 95, Training Loss = 1.9035426378250122
# Batch id 96, Training Loss = 1.8951992988586426
# Batch id 97, Training Loss = 1.8947396278381348
# Batch id 98, Training Loss = 1.8907361030578613
# Batch id 99, Training Loss = 1.8858513832092285
# Batch id 100, Training Loss = 1.8819019794464111
# Batch id 101, Training Loss = 1.880017876625061
# Batch id 102, Training Loss = 1.8748193979263306
# Batch id 103, Training Loss = 1.867333173751831
# Batch id 104, Training Loss = 1.8632251024246216
# Batch id 105, Training Loss = 1.852481484413147
# Batch id 106, Training Loss = 1.84409761428833
# Batch id 107, Training Loss = 1.8383134603500366
# Batch id 108, Training Loss = 1.8339483737945557
# Batch id 109, Training Loss = 1.8286962509155273
# Batch id 110, Training Loss = 1.8222906589508057
# Batch id 111, Training Loss = 1.8208014965057373
# Batch id 112, Training Loss = 1.8118585348129272
# Batch id 113, Training Loss = 1.8042362928390503
# Batch id 114, Training Loss = 1.7979483604431152
# Batch id 115, Training Loss = 1.7879867553710938
# Batch id 116, Training Loss = 1.7813584804534912
# Batch id 117, Training Loss = 1.7776919603347778
# Batch id 118, Training Loss = 1.7737679481506348
# Batch id 119, Training Loss = 1.7683963775634766
# Batch id 120, Training Loss = 1.7671865224838257
# Batch id 121, Training Loss = 1.7615947723388672
# Batch id 122, Training Loss = 1.7569189071655273
# Batch id 123, Training Loss = 1.7574896812438965
# Batch id 124, Training Loss = 1.7518072128295898
# Batch id 125, Training Loss = 1.7474795579910278
# Batch id 126, Training Loss = 1.7388542890548706
# Batch id 127, Training Loss = 1.7359610795974731
# Batch id 128, Training Loss = 1.7387646436691284
# Batch id 129, Training Loss = 1.7364187240600586
# Batch id 130, Training Loss = 1.7325098514556885
# Batch id 131, Training Loss = 1.7307027578353882
# Batch id 132, Training Loss = 1.7256513833999634
# Batch id 133, Training Loss = 1.7210400104522705
# Batch id 134, Training Loss = 1.716850996017456
# Batch id 135, Training Loss = 1.7114171981811523
# Batch id 136, Training Loss = 1.7079074382781982
# Batch id 137, Training Loss = 1.7001135349273682
# Batch id 138, Training Loss = 1.6996665000915527
# Batch id 139, Training Loss = 1.6958179473876953
# Batch id 140, Training Loss = 1.6955575942993164
# Batch id 141, Training Loss = 1.6907083988189697
# Batch id 142, Training Loss = 1.6863232851028442
# Batch id 143, Training Loss = 1.6811950206756592
# Batch id 144, Training Loss = 1.6743056774139404
# Batch id 145, Training Loss = 1.6668883562088013
# Batch id 146, Training Loss = 1.6646062135696411
# Batch id 147, Training Loss = 1.6603093147277832
# Batch id 148, Training Loss = 1.658136010169983
# Batch id 149, Training Loss = 1.6553854942321777
# Batch id 150, Training Loss = 1.6538809537887573
# Batch id 151, Training Loss = 1.6516212224960327
# Batch id 152, Training Loss = 1.6569340229034424
# Batch id 153, Training Loss = 1.6585060358047485
# Batch id 154, Training Loss = 1.6540462970733643
# Batch id 155, Training Loss = 1.650983214378357
# Batch id 156, Training Loss = 1.6456246376037598
# Batch id 157, Training Loss = 1.6415141820907593
# Batch id 158, Training Loss = 1.6358039379119873
# Batch id 159, Training Loss = 1.6310123205184937
# Batch id 160, Training Loss = 1.6279593706130981
# Batch id 161, Training Loss = 1.627350926399231
# Batch id 162, Training Loss = 1.6246587038040161
# Batch id 163, Training Loss = 1.621010661125183
# Batch id 164, Training Loss = 1.6185688972473145
# Batch id 165, Training Loss = 1.6134462356567383
# Batch id 166, Training Loss = 1.613379716873169
# Batch id 167, Training Loss = 1.609572172164917
# Batch id 168, Training Loss = 1.6031548976898193
# Batch id 169, Training Loss = 1.6021760702133179
# Batch id 170, Training Loss = 1.599907636642456
# Batch id 171, Training Loss = 1.5967133045196533
# Batch id 172, Training Loss = 1.598282814025879
# Batch id 173, Training Loss = 1.593889594078064
# Batch id 174, Training Loss = 1.5954254865646362
# Batch id 175, Training Loss = 1.5921978950500488
# Batch id 176, Training Loss = 1.588923692703247
# Batch id 177, Training Loss = 1.5849055051803589
# Batch id 178, Training Loss = 1.5832902193069458
# Batch id 179, Training Loss = 1.5815757513046265
# Batch id 180, Training Loss = 1.5773741006851196
# Batch id 181, Training Loss = 1.5733413696289062
# Batch id 182, Training Loss = 1.5709125995635986
# Batch id 183, Training Loss = 1.5698846578598022
# Batch id 184, Training Loss = 1.5691931247711182
# Batch id 185, Training Loss = 1.5659419298171997
# Batch id 186, Training Loss = 1.5624102354049683
# Batch id 187, Training Loss = 1.5571969747543335
# Batch id 188, Training Loss = 1.5545995235443115
# Batch id 189, Training Loss = 1.5515483617782593
# Batch id 190, Training Loss = 1.5493546724319458
# Batch id 191, Training Loss = 1.547419786453247
# Batch id 192, Training Loss = 1.5472242832183838
# Batch id 193, Training Loss = 1.5450737476348877
# Batch id 194, Training Loss = 1.540718913078308
# Batch id 195, Training Loss = 1.5356303453445435
# Batch id 196, Training Loss = 1.5334076881408691
# Batch id 197, Training Loss = 1.5323387384414673
# Batch id 198, Training Loss = 1.5290472507476807
# Batch id 199, Training Loss = 1.5253676176071167
# Batch id 200, Training Loss = 1.5239524841308594
# Batch id 201, Training Loss = 1.5221548080444336
# Batch id 202, Training Loss = 1.5192317962646484
# Batch id 203, Training Loss = 1.5159169435501099
# Batch id 204, Training Loss = 1.5117557048797607
# Batch id 205, Training Loss = 1.5074830055236816
# Batch id 206, Training Loss = 1.5083380937576294
# Batch id 207, Training Loss = 1.5082848072052002
# Batch id 208, Training Loss = 1.5045273303985596
# Finished epoch: 1 	Training Loss: 1.504527 	Validation Loss: 0.496274
# Validation loss decreased (inf --> 0.496274).  Saving model ...
# Batch id 0, Training Loss = 0.7093755006790161
# Batch id 1, Training Loss = 0.40813708305358887
# Batch id 2, Training Loss = 0.4871467053890228
# Batch id 3, Training Loss = 0.47505664825439453
# Batch id 4, Training Loss = 0.5144630074501038
# Batch id 5, Training Loss = 0.4677354693412781
# Batch id 6, Training Loss = 0.4830092489719391
# Batch id 7, Training Loss = 0.5105026364326477
# Batch id 8, Training Loss = 0.5607137680053711
# Batch id 9, Training Loss = 0.5981703400611877
# Batch id 10, Training Loss = 0.599957287311554
# Batch id 11, Training Loss = 0.6089035868644714
# Batch id 12, Training Loss = 0.633181095123291
# Batch id 13, Training Loss = 0.6070783734321594
# Batch id 14, Training Loss = 0.6450545787811279
# Batch id 15, Training Loss = 0.6318120360374451
# Batch id 16, Training Loss = 0.6222363710403442
# Batch id 17, Training Loss = 0.6243430376052856
# Batch id 18, Training Loss = 0.6223174929618835
# Batch id 19, Training Loss = 0.6214804649353027
# Batch id 20, Training Loss = 0.6276025772094727
# Batch id 21, Training Loss = 0.617255687713623
# Batch id 22, Training Loss = 0.6369330883026123
# Batch id 23, Training Loss = 0.6371336579322815
# Batch id 24, Training Loss = 0.6433607935905457
# Batch id 25, Training Loss = 0.6484732627868652
# Batch id 26, Training Loss = 0.6536122560501099
# Batch id 29, Training Loss = 0.7086083292961121
# Batch id 30, Training Loss = 0.7005765438079834
# Batch id 31, Training Loss = 0.6905770897865295
# Batch id 32, Training Loss = 0.6831610202789307
# Batch id 33, Training Loss = 0.6871862411499023
# Batch id 34, Training Loss = 0.6939260959625244
# Batch id 35, Training Loss = 0.6903172731399536
# Batch id 36, Training Loss = 0.7010788321495056
# Batch id 37, Training Loss = 0.7290481328964233
# Batch id 38, Training Loss = 0.7324765920639038
# Batch id 39, Training Loss = 0.7323890924453735
# Batch id 40, Training Loss = 0.7303062677383423
# Batch id 41, Training Loss = 0.7313748002052307
# Batch id 42, Training Loss = 0.7230061888694763
# Batch id 43, Training Loss = 0.7140613794326782
# Batch id 44, Training Loss = 0.7071481943130493
# Batch id 45, Training Loss = 0.7026036977767944
# Batch id 46, Training Loss = 0.7005887627601624
# Batch id 47, Training Loss = 0.6962801814079285
# Batch id 48, Training Loss = 0.7006780505180359
# Batch id 49, Training Loss = 0.6943483948707581
# Batch id 50, Training Loss = 0.694369912147522
# Batch id 51, Training Loss = 0.6920332312583923
# Batch id 52, Training Loss = 0.6923621892929077
# Batch id 53, Training Loss = 0.6878758072853088
# Batch id 54, Training Loss = 0.6917553544044495
# Batch id 55, Training Loss = 0.6956212520599365
# Batch id 56, Training Loss = 0.6998509764671326
# Batch id 57, Training Loss = 0.6946907043457031
# Batch id 58, Training Loss = 0.6917999386787415
# Batch id 59, Training Loss = 0.6896061897277832
# Batch id 60, Training Loss = 0.6915369629859924
# Batch id 61, Training Loss = 0.6943522095680237
# Batch id 62, Training Loss = 0.7159824967384338
# Batch id 63, Training Loss = 0.7147040367126465
# Batch id 64, Training Loss = 0.7087010145187378
# Batch id 65, Training Loss = 0.7032195329666138
# Batch id 66, Training Loss = 0.7029954791069031
# Batch id 67, Training Loss = 0.7089630961418152
# Batch id 68, Training Loss = 0.7119510769844055
# Batch id 69, Training Loss = 0.7167055606842041
# Batch id 70, Training Loss = 0.7132647633552551
# Batch id 71, Training Loss = 0.7120633721351624
# Batch id 72, Training Loss = 0.7089205980300903
# Batch id 73, Training Loss = 0.7056679129600525
# Batch id 74, Training Loss = 0.70423823595047
# Batch id 75, Training Loss = 0.7057182788848877
# Batch id 76, Training Loss = 0.7050071358680725
# Batch id 77, Training Loss = 0.703289270401001
# Batch id 78, Training Loss = 0.7079018354415894
# Batch id 79, Training Loss = 0.7060967087745667
# Batch id 80, Training Loss = 0.7079218626022339
# Batch id 81, Training Loss = 0.7098973989486694
# Batch id 82, Training Loss = 0.7079339027404785
# Batch id 83, Training Loss = 0.7076744437217712
# Batch id 84, Training Loss = 0.708893358707428
# Batch id 85, Training Loss = 0.7120355367660522
# Batch id 86, Training Loss = 0.7118092775344849
# Batch id 87, Training Loss = 0.7119802236557007
# Batch id 88, Training Loss = 0.7098888158798218
# Batch id 89, Training Loss = 0.7119962573051453
# Batch id 90, Training Loss = 0.7089765667915344
# Batch id 91, Training Loss = 0.706384003162384
# Batch id 92, Training Loss = 0.7056662440299988
# Batch id 93, Training Loss = 0.7135761976242065
# Batch id 94, Training Loss = 0.7132684588432312
# Batch id 95, Training Loss = 0.7101055383682251
# Batch id 96, Training Loss = 0.7137241959571838
# Batch id 97, Training Loss = 0.7153584361076355
# Batch id 98, Training Loss = 0.7181687355041504
# Batch id 99, Training Loss = 0.7184731364250183
# Batch id 100, Training Loss = 0.7242911458015442
# Batch id 101, Training Loss = 0.7242063879966736
# Batch id 102, Training Loss = 0.7265009880065918
# Batch id 103, Training Loss = 0.7247737050056458
# Batch id 104, Training Loss = 0.7246226668357849
# Batch id 105, Training Loss = 0.7258731126785278
# Batch id 106, Training Loss = 0.7281221747398376
# Batch id 107, Training Loss = 0.7307932376861572
# Batch id 108, Training Loss = 0.7279707193374634
# Batch id 109, Training Loss = 0.7290056347846985
# Batch id 110, Training Loss = 0.7243369221687317
# Batch id 111, Training Loss = 0.7264717221260071
# Batch id 112, Training Loss = 0.7245538234710693
# Batch id 113, Training Loss = 0.7223445773124695
# Batch id 114, Training Loss = 0.7180584669113159
# Batch id 115, Training Loss = 0.7164276838302612
# Batch id 116, Training Loss = 0.7158939838409424
# Batch id 117, Training Loss = 0.7148470878601074
# Batch id 118, Training Loss = 0.7133702635765076
# Batch id 119, Training Loss = 0.7127721905708313
# Batch id 120, Training Loss = 0.7139177322387695
# Batch id 121, Training Loss = 0.7118534445762634
# Batch id 122, Training Loss = 0.7130193114280701
# Batch id 123, Training Loss = 0.7168181538581848
# Batch id 124, Training Loss = 0.720603883266449
# Batch id 125, Training Loss = 0.7221632599830627
# Batch id 126, Training Loss = 0.7227866053581238
# Batch id 127, Training Loss = 0.7229543924331665
# Batch id 128, Training Loss = 0.7200528979301453
# Batch id 129, Training Loss = 0.722413957118988
# Batch id 130, Training Loss = 0.7255656123161316
# Batch id 131, Training Loss = 0.728134274482727
# Batch id 132, Training Loss = 0.7302623391151428
# Batch id 133, Training Loss = 0.7299965620040894
# Batch id 134, Training Loss = 0.727968156337738
# Batch id 135, Training Loss = 0.7286974787712097
# Batch id 136, Training Loss = 0.7309435606002808
# Batch id 137, Training Loss = 0.7310431003570557
# Batch id 138, Training Loss = 0.7325347661972046
# Batch id 139, Training Loss = 0.7335904836654663
# Batch id 140, Training Loss = 0.7337197661399841
# Batch id 141, Training Loss = 0.7378634214401245
# Batch id 142, Training Loss = 0.7351908683776855
# Batch id 143, Training Loss = 0.7352827787399292
# Batch id 144, Training Loss = 0.7375730872154236
# Batch id 145, Training Loss = 0.7379360795021057
# Batch id 146, Training Loss = 0.7353646755218506
# Batch id 147, Training Loss = 0.7336441874504089
# Batch id 148, Training Loss = 0.7335188388824463
# Batch id 149, Training Loss = 0.7326542139053345
# Batch id 150, Training Loss = 0.7333834171295166
# Batch id 151, Training Loss = 0.7343174815177917
# Batch id 152, Training Loss = 0.7344580888748169
# Batch id 153, Training Loss = 0.7330584526062012
# Batch id 154, Training Loss = 0.7319394946098328
# Batch id 155, Training Loss = 0.7324082255363464
# Batch id 156, Training Loss = 0.7306069731712341
# Batch id 157, Training Loss = 0.7395192384719849
# Batch id 158, Training Loss = 0.7406387329101562
# Batch id 159, Training Loss = 0.7389055490493774
# Batch id 160, Training Loss = 0.7386198043823242
# Batch id 161, Training Loss = 0.7435195446014404
# Batch id 162, Training Loss = 0.7467390298843384
# Batch id 163, Training Loss = 0.7462710738182068
# Batch id 164, Training Loss = 0.7472410798072815
# Batch id 165, Training Loss = 0.7464640140533447
# Batch id 166, Training Loss = 0.7458529472351074
# Batch id 167, Training Loss = 0.7440789341926575
# Batch id 168, Training Loss = 0.7423569560050964
# Batch id 169, Training Loss = 0.7471064925193787
# Batch id 170, Training Loss = 0.7466892600059509
# Batch id 171, Training Loss = 0.7448524832725525
# Batch id 172, Training Loss = 0.7438666820526123
# Batch id 173, Training Loss = 0.7440330982208252
# Batch id 174, Training Loss = 0.7421684265136719
# Batch id 175, Training Loss = 0.7428914308547974
# Batch id 176, Training Loss = 0.7419580221176147
# Batch id 177, Training Loss = 0.7411704063415527
# Batch id 178, Training Loss = 0.7413428425788879
# Batch id 179, Training Loss = 0.7412378787994385
# Batch id 180, Training Loss = 0.7406890988349915
# Batch id 181, Training Loss = 0.7412223815917969
# Batch id 182, Training Loss = 0.7401694059371948
# Batch id 183, Training Loss = 0.739260733127594
# Batch id 184, Training Loss = 0.7394598126411438
# Batch id 185, Training Loss = 0.7388617396354675
# Batch id 186, Training Loss = 0.7389190793037415
# Batch id 187, Training Loss = 0.7383224964141846
# Batch id 188, Training Loss = 0.736129641532898
# Batch id 189, Training Loss = 0.7402732372283936
# Batch id 190, Training Loss = 0.7386817336082458
# Batch id 191, Training Loss = 0.739075243473053
# Batch id 192, Training Loss = 0.7409718036651611
# Batch id 193, Training Loss = 0.742950975894928
# Batch id 194, Training Loss = 0.7420759201049805
# Batch id 195, Training Loss = 0.7425073981285095
# Batch id 196, Training Loss = 0.7413138151168823
# Batch id 197, Training Loss = 0.7405533790588379
# Batch id 198, Training Loss = 0.7420473694801331
# Batch id 199, Training Loss = 0.7447257041931152
# Batch id 200, Training Loss = 0.7428943514823914
# Batch id 201, Training Loss = 0.7434464693069458
# Batch id 202, Training Loss = 0.742715060710907
# Batch id 203, Training Loss = 0.7450371980667114
# Batch id 204, Training Loss = 0.746673047542572
# Batch id 205, Training Loss = 0.7486131191253662
# Batch id 206, Training Loss = 0.7519772052764893
# Batch id 207, Training Loss = 0.7508111000061035
# Batch id 208, Training Loss = 0.7505851984024048
# Finished epoch: 2 	Training Loss: 0.750585 	Validation Loss: 0.346164
# Validation loss decreased (0.496274 --> 0.346164).  Saving model ...
# Batch id 0, Training Loss = 0.593582272529602
# Batch id 1, Training Loss = 0.7003644704818726
# Batch id 2, Training Loss = 0.6607446074485779
# Batch id 3, Training Loss = 0.5793995261192322
# Batch id 4, Training Loss = 0.5332558751106262
# Batch id 5, Training Loss = 0.556852400302887
# Batch id 6, Training Loss = 0.5090286731719971
# Batch id 7, Training Loss = 0.5008342862129211
# Batch id 8, Training Loss = 0.47909122705459595
# Batch id 9, Training Loss = 0.48031970858573914
# Batch id 10, Training Loss = 0.4952598214149475
# Batch id 11, Training Loss = 0.48272085189819336
# Batch id 12, Training Loss = 0.4866412580013275
# Batch id 13, Training Loss = 0.47944340109825134
# Batch id 14, Training Loss = 0.48704415559768677
# Batch id 15, Training Loss = 0.4993017911911011
# Batch id 16, Training Loss = 0.49851658940315247
# Batch id 17, Training Loss = 0.516980767250061
# Batch id 18, Training Loss = 0.5336463451385498
# Batch id 19, Training Loss = 0.5262842774391174
# Batch id 20, Training Loss = 0.5370156168937683
# Batch id 21, Training Loss = 0.537068784236908
# Batch id 22, Training Loss = 0.5543131828308105
# Batch id 23, Training Loss = 0.5528529286384583
# Batch id 24, Training Loss = 0.5521056652069092
# Batch id 25, Training Loss = 0.5624964833259583
# Batch id 26, Training Loss = 0.5651878714561462
# Batch id 27, Training Loss = 0.5650703310966492
# Batch id 28, Training Loss = 0.5706153512001038
# Batch id 29, Training Loss = 0.5845851898193359
# Batch id 30, Training Loss = 0.577866792678833
# Batch id 31, Training Loss = 0.5741258263587952
# Batch id 32, Training Loss = 0.5684976577758789
# Batch id 33, Training Loss = 0.55839604139328
# Batch id 34, Training Loss = 0.5648389458656311
# Batch id 35, Training Loss = 0.5550696849822998
# Batch id 36, Training Loss = 0.546330451965332
# Batch id 37, Training Loss = 0.5476497411727905
# Batch id 38, Training Loss = 0.5393645167350769
# Batch id 39, Training Loss = 0.5345192551612854
# Batch id 40, Training Loss = 0.5327582359313965
# Batch id 41, Training Loss = 0.535679817199707
# Batch id 42, Training Loss = 0.5330480337142944
# Batch id 43, Training Loss = 0.5321149826049805
# Batch id 44, Training Loss = 0.5252406001091003
# Batch id 45, Training Loss = 0.5219940543174744
# Batch id 46, Training Loss = 0.5187408924102783
# Batch id 47, Training Loss = 0.5177263617515564
# Batch id 48, Training Loss = 0.5153795480728149
# Batch id 49, Training Loss = 0.514538586139679
# Batch id 50, Training Loss = 0.5070692300796509
# Batch id 51, Training Loss = 0.5077224373817444
# Batch id 52, Training Loss = 0.5065577030181885
# Batch id 53, Training Loss = 0.499392569065094
# Batch id 54, Training Loss = 0.49908697605133057
# Batch id 55, Training Loss = 0.4993840754032135
# Batch id 56, Training Loss = 0.5111731886863708
# Batch id 57, Training Loss = 0.5063405632972717
# Batch id 58, Training Loss = 0.5028592944145203
# Batch id 59, Training Loss = 0.5037662386894226
# Batch id 60, Training Loss = 0.4967786967754364
# Batch id 61, Training Loss = 0.4960140883922577
# Batch id 62, Training Loss = 0.4983328878879547
# Batch id 63, Training Loss = 0.4974636435508728
# Batch id 64, Training Loss = 0.49224334955215454
# Batch id 65, Training Loss = 0.4897681474685669
# Batch id 66, Training Loss = 0.4882490932941437
# Batch id 67, Training Loss = 0.49330636858940125
# Batch id 68, Training Loss = 0.49306389689445496
# Batch id 69, Training Loss = 0.4889290928840637
# Batch id 70, Training Loss = 0.49137362837791443
# Batch id 71, Training Loss = 0.48978132009506226
# Batch id 72, Training Loss = 0.49133825302124023
# Batch id 73, Training Loss = 0.4906916916370392
# Batch id 74, Training Loss = 0.48987507820129395
# Batch id 75, Training Loss = 0.48625195026397705
# Batch id 76, Training Loss = 0.48271095752716064
# Batch id 77, Training Loss = 0.48287248611450195
# Batch id 78, Training Loss = 0.4793437123298645
# Batch id 79, Training Loss = 0.47856616973876953
# Batch id 80, Training Loss = 0.4830615818500519
# Batch id 81, Training Loss = 0.48422545194625854
# Batch id 82, Training Loss = 0.4826706647872925
# Batch id 83, Training Loss = 0.48268720507621765
# Batch id 84, Training Loss = 0.48561525344848633
# Batch id 85, Training Loss = 0.48308613896369934
# Batch id 86, Training Loss = 0.48090729117393494
# Batch id 87, Training Loss = 0.484640896320343
# Batch id 88, Training Loss = 0.4829656481742859
# Batch id 89, Training Loss = 0.48294347524642944
# Batch id 90, Training Loss = 0.4826391041278839
# Batch id 91, Training Loss = 0.4824109375476837
# Batch id 92, Training Loss = 0.48102840781211853
# Batch id 93, Training Loss = 0.47975412011146545
# Batch id 94, Training Loss = 0.48104631900787354
# Batch id 95, Training Loss = 0.47925177216529846
# Batch id 96, Training Loss = 0.4798179268836975
# Batch id 97, Training Loss = 0.47728830575942993
# Batch id 98, Training Loss = 0.48250746726989746
# Batch id 99, Training Loss = 0.4815908372402191
# Batch id 100, Training Loss = 0.48376619815826416
# Batch id 101, Training Loss = 0.48480263352394104
# Batch id 102, Training Loss = 0.485359251499176
# Batch id 103, Training Loss = 0.4817372262477875
# Batch id 104, Training Loss = 0.47940123081207275
# Batch id 105, Training Loss = 0.4835391342639923
# Batch id 106, Training Loss = 0.48241743445396423
# Batch id 107, Training Loss = 0.4851391613483429
# Batch id 108, Training Loss = 0.4853140711784363
# Batch id 109, Training Loss = 0.48386630415916443
# Batch id 110, Training Loss = 0.48576390743255615
# Batch id 111, Training Loss = 0.48573538661003113
# Batch id 112, Training Loss = 0.48341867327690125
# Batch id 113, Training Loss = 0.4824899435043335
# Batch id 114, Training Loss = 0.47963330149650574
# Batch id 115, Training Loss = 0.4785677492618561
# Batch id 116, Training Loss = 0.47729164361953735
# Batch id 117, Training Loss = 0.4752902686595917
# Batch id 118, Training Loss = 0.4739066958427429
# Batch id 119, Training Loss = 0.4730631411075592
# Batch id 120, Training Loss = 0.47315332293510437
# Batch id 121, Training Loss = 0.47133901715278625
# Batch id 122, Training Loss = 0.4737130105495453
# Batch id 123, Training Loss = 0.47374972701072693
# Batch id 124, Training Loss = 0.4797228276729584
# Batch id 125, Training Loss = 0.48330092430114746
# Batch id 126, Training Loss = 0.4813655614852905
# Batch id 127, Training Loss = 0.4908279478549957
# Batch id 128, Training Loss = 0.49296942353248596
# Batch id 129, Training Loss = 0.4973037540912628
# Batch id 130, Training Loss = 0.49747762084007263
# Batch id 131, Training Loss = 0.5000814199447632
# Batch id 132, Training Loss = 0.4995083212852478
# Batch id 133, Training Loss = 0.4968336224555969
# Batch id 134, Training Loss = 0.49474790692329407
# Batch id 135, Training Loss = 0.49490660429000854
# Batch id 136, Training Loss = 0.4934772253036499
# Batch id 137, Training Loss = 0.491524338722229
# Batch id 138, Training Loss = 0.4912838935852051
# Batch id 139, Training Loss = 0.49052000045776367
# Batch id 140, Training Loss = 0.4903026819229126
# Batch id 141, Training Loss = 0.489883154630661
# Batch id 142, Training Loss = 0.48983970284461975
# Batch id 143, Training Loss = 0.48823633790016174
# Batch id 144, Training Loss = 0.4866977334022522
# Batch id 145, Training Loss = 0.48544207215309143
# Batch id 146, Training Loss = 0.48434051871299744
# Batch id 147, Training Loss = 0.48494869470596313
# Batch id 148, Training Loss = 0.4865104556083679
# Batch id 149, Training Loss = 0.48713332414627075
# Batch id 150, Training Loss = 0.4896579086780548
# Batch id 151, Training Loss = 0.4927389919757843
# Batch id 152, Training Loss = 0.494050532579422
# Batch id 153, Training Loss = 0.49618151783943176
# Batch id 154, Training Loss = 0.4970311224460602
# Batch id 155, Training Loss = 0.4963684678077698
# Batch id 156, Training Loss = 0.49554482102394104
# Batch id 157, Training Loss = 0.494244247674942
# Batch id 158, Training Loss = 0.49376586079597473
# Batch id 159, Training Loss = 0.4928693473339081
# Batch id 160, Training Loss = 0.4943625330924988
# Batch id 161, Training Loss = 0.494036465883255
# Batch id 162, Training Loss = 0.49391964077949524
# Batch id 163, Training Loss = 0.49291592836380005
# Batch id 164, Training Loss = 0.4930853247642517
# Batch id 165, Training Loss = 0.4938396215438843
# Batch id 166, Training Loss = 0.4935944676399231
# Batch id 167, Training Loss = 0.49417489767074585
# Batch id 168, Training Loss = 0.49641862511634827
# Batch id 169, Training Loss = 0.49799516797065735
# Batch id 170, Training Loss = 0.49980825185775757
# Batch id 171, Training Loss = 0.4990280270576477
# Batch id 172, Training Loss = 0.4984189569950104
# Batch id 173, Training Loss = 0.4975605309009552
# Batch id 174, Training Loss = 0.49745360016822815
# Batch id 175, Training Loss = 0.4973810017108917
# Batch id 176, Training Loss = 0.49605250358581543
# Batch id 177, Training Loss = 0.49698925018310547
# Batch id 178, Training Loss = 0.49599552154541016
# Batch id 179, Training Loss = 0.4971330463886261
# Batch id 180, Training Loss = 0.5010617971420288
# Batch id 181, Training Loss = 0.4996657073497772
# Batch id 182, Training Loss = 0.5005602240562439
# Batch id 183, Training Loss = 0.5010979771614075
# Batch id 184, Training Loss = 0.49986472725868225
# Batch id 185, Training Loss = 0.4992275834083557
# Batch id 186, Training Loss = 0.4977584183216095
# Batch id 187, Training Loss = 0.5023437738418579
# Batch id 188, Training Loss = 0.5014079809188843
# Batch id 189, Training Loss = 0.5018336176872253
# Batch id 190, Training Loss = 0.5024964809417725
# Batch id 191, Training Loss = 0.5017475485801697
# Batch id 192, Training Loss = 0.5006189942359924
# Batch id 193, Training Loss = 0.5000540614128113
# Batch id 194, Training Loss = 0.49882879853248596
# Batch id 195, Training Loss = 0.49908941984176636
# Batch id 196, Training Loss = 0.49777641892433167
# Batch id 197, Training Loss = 0.496773362159729
# Batch id 198, Training Loss = 0.49800342321395874
# Batch id 199, Training Loss = 0.4977794587612152
# Batch id 200, Training Loss = 0.49856168031692505
# Batch id 201, Training Loss = 0.5001795887947083
# Batch id 202, Training Loss = 0.5019976496696472
# Batch id 203, Training Loss = 0.5021687150001526
# Batch id 204, Training Loss = 0.5013542771339417
# Batch id 205, Training Loss = 0.5002363920211792
# Batch id 206, Training Loss = 0.49832627177238464
# Batch id 207, Training Loss = 0.49926167726516724
# Batch id 208, Training Loss = 0.49967464804649353
# Finished epoch: 3 	Training Loss: 0.499675 	Validation Loss: 0.243631
# Validation loss decreased (0.346164 --> 0.243631).  Saving model ...

# %% [markdown]
# ### (IMPLEMENTATION) Test the Model
#
# Try out your model on the test dataset of dog images. Use the code cell below to calculate and print the test loss and accuracy.  Ensure that your test accuracy is greater than 60%.

# %%
test(loaders_transfer, model_transfer, criterion_transfer, use_cuda)
# Out:
# Test Loss: 0.243631
#
#
# Test Accuracy: 94% (6294/6680)

# %% [markdown]
# ### Attempts
# - Training with 3 epochs replacing last layer of VGG with 133 outputs
#     - 94% of accuracy

# %% [markdown]
# ### (IMPLEMENTATION) Predict Dog Breed with the Model
#
# Write a function that takes an image path as input and returns the dog breed (`Affenpinscher`, `Afghan hound`, etc) that is predicted by your model.

# %%
train_set.classes
# Out:
# ['001.Affenpinscher',
#  '002.Afghan_hound',
#  '003.Airedale_terrier',
#  '004.Akita',
#  '005.Alaskan_malamute',
#  '006.American_eskimo_dog',
#  '007.American_foxhound',
#  '008.American_staffordshire_terrier',
#  '009.American_water_spaniel',
#  '010.Anatolian_shepherd_dog',
#  '011.Australian_cattle_dog',
#  '012.Australian_shepherd',
#  '013.Australian_terrier',
#  '014.Basenji',
#  '015.Basset_hound',
#  '016.Beagle',
#  '017.Bearded_collie',
#  '018.Beauceron',
#  '019.Bedlington_terrier',
#  '020.Belgian_malinois',
#  '021.Belgian_sheepdog',
#  '022.Belgian_tervuren',
#  '023.Bernese_mountain_dog',
#  '024.Bichon_frise',
#  '025.Black_and_tan_coonhound',
#  '026.Black_russian_terrier',
#  '027.Bloodhound',
#  '028.Bluetick_coonhound',
#  '029.Border_collie',
#  '030.Border_terrier',
#  '031.Borzoi',
#  '032.Boston_terrier',
#  '033.Bouvier_des_flandres',
#  '034.Boxer',
#  '035.Boykin_spaniel',
#  '036.Briard',
#  '037.Brittany',
#  '038.Brussels_griffon',
#  '039.Bull_terrier',
#  '040.Bulldog',
#  '041.Bullmastiff',
#  '042.Cairn_terrier',
#  '043.Canaan_dog',
#  '044.Cane_corso',
#  '045.Cardigan_welsh_corgi',
#  '046.Cavalier_king_charles_spaniel',
#  '047.Chesapeake_bay_retriever',
#  '048.Chihuahua',
#  '049.Chinese_crested',
#  '050.Chinese_shar-pei',
#  '051.Chow_chow',
#  '052.Clumber_spaniel',
#  '053.Cocker_spaniel',
#  '054.Collie',
#  '055.Curly-coated_retriever',
#  '056.Dachshund',
#  '057.Dalmatian',
#  '058.Dandie_dinmont_terrier',
#  '059.Doberman_pinscher',
#  '060.Dogue_de_bordeaux',
#  '061.English_cocker_spaniel',
#  '062.English_setter',
#  '063.English_springer_spaniel',
#  '064.English_toy_spaniel',
#  '065.Entlebucher_mountain_dog',
#  '066.Field_spaniel',
#  '067.Finnish_spitz',
#  '068.Flat-coated_retriever',
#  '069.French_bulldog',
#  '070.German_pinscher',
#  '071.German_shepherd_dog',
#  '072.German_shorthaired_pointer',
#  '073.German_wirehaired_pointer',
#  '074.Giant_schnauzer',
#  '075.Glen_of_imaal_terrier',
#  '076.Golden_retriever',
#  '077.Gordon_setter',
#  '078.Great_dane',
#  '079.Great_pyrenees',
#  '080.Greater_swiss_mountain_dog',
#  '081.Greyhound',
#  '082.Havanese',
#  '083.Ibizan_hound',
#  '084.Icelandic_sheepdog',
#  '085.Irish_red_and_white_setter',
#  '086.Irish_setter',
#  '087.Irish_terrier',
#  '088.Irish_water_spaniel',
#  '089.Irish_wolfhound',
#  '090.Italian_greyhound',
#  '091.Japanese_chin',
#  '092.Keeshond',
#  '093.Kerry_blue_terrier',
#  '094.Komondor',
#  '095.Kuvasz',
#  '096.Labrador_retriever',
#  '097.Lakeland_terrier',
#  '098.Leonberger',
#  '099.Lhasa_apso',
#  '100.Lowchen',
#  '101.Maltese',
#  '102.Manchester_terrier',
#  '103.Mastiff',
#  '104.Miniature_schnauzer',
#  '105.Neapolitan_mastiff',
#  '106.Newfoundland',
#  '107.Norfolk_terrier',
#  '108.Norwegian_buhund',
#  '109.Norwegian_elkhound',
#  '110.Norwegian_lundehund',
#  '111.Norwich_terrier',
#  '112.Nova_scotia_duck_tolling_retriever',
#  '113.Old_english_sheepdog',
#  '114.Otterhound',
#  '115.Papillon',
#  '116.Parson_russell_terrier',
#  '117.Pekingese',
#  '118.Pembroke_welsh_corgi',
#  '119.Petit_basset_griffon_vendeen',
#  '120.Pharaoh_hound',
#  '121.Plott',
#  '122.Pointer',
#  '123.Pomeranian',
#  '124.Poodle',
#  '125.Portuguese_water_dog',
#  '126.Saint_bernard',
#  '127.Silky_terrier',
#  '128.Smooth_fox_terrier',
#  '129.Tibetan_mastiff',
#  '130.Welsh_springer_spaniel',
#  '131.Wirehaired_pointing_griffon',
#  '132.Xoloitzcuintli',
#  '133.Yorkshire_terrier']

# %%
### TODO: Write a function that takes a path to an image as input
### and returns the dog breed that is predicted by the model.

# list of class names by index, i.e. a name can be accessed like class_names[0]
class_names = [item[4:].replace("_", " ") for item in train_set.classes]

def predict_breed_transfer(img_path):
    normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                 std=[0.229, 0.224, 0.225])
    transform = transforms.Compose([
        transforms.Resize(224),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        normalize
    ])
    
    
    img = Image.open(img_path)
    img = transform(img)
    # Add batch dimension
    img = img.unsqueeze(0)
    if use_cuda:
        img = img.cuda()
    pred = model_transfer.forward(img)
    _, class_idx = pred.max(1)
    
    return class_names[class_idx.item()]

# %%
img_path = '/data/dog_images/train/059.Doberman_pinscher/Doberman_pinscher_04192.jpg'
predict_breed_transfer(img_path)
# Out:
# 'Doberman pinscher'

# %%
# !wget https://raw.githubusercontent.com/WittmannF/dog-breed-classifier/master/idk.jpg
# Out:
# --2019-05-01 19:39:34--  https://raw.githubusercontent.com/WittmannF/dog-breed-classifier/master/idk.jpg
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 865330 (845K) [image/jpeg]
# Saving to: ‘idk.jpg.1’
#
# idk.jpg.1           100%[===================>] 845.05K  --.-KB/s    in 0.06s
#
# 2019-05-01 19:39:35 (13.6 MB/s) - ‘idk.jpg.1’ saved [865330/865330]

# %%
# !wget https://raw.githubusercontent.com/WittmannF/dog-breed-classifier/master/labrador.jpg
# !wget https://raw.githubusercontent.com/WittmannF/dog-breed-classifier/master/lobinho1.jpg
# !wget https://raw.githubusercontent.com/WittmannF/dog-breed-classifier/master/lobinho2.jpg
# !wget https://raw.githubusercontent.com/WittmannF/dog-breed-classifier/master/notsure.jpg
# !wget https://raw.githubusercontent.com/WittmannF/dog-breed-classifier/master/pug.jpg
# Out:
# --2019-05-01 19:39:40--  https://raw.githubusercontent.com/WittmannF/dog-breed-classifier/master/labrador.jpg
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 168833 (165K) [image/jpeg]
# Saving to: ‘labrador.jpg.1’
#
# labrador.jpg.1      100%[===================>] 164.88K  --.-KB/s    in 0.03s
#
# 2019-05-01 19:39:40 (5.33 MB/s) - ‘labrador.jpg.1’ saved [168833/168833]
#
# --2019-05-01 19:39:41--  https://raw.githubusercontent.com/WittmannF/dog-breed-classifier/master/lobinho1.jpg
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1642262 (1.6M) [image/jpeg]
# Saving to: ‘lobinho1.jpg.1’
#
# lobinho1.jpg.1      100%[===================>]   1.57M  --.-KB/s    in 0.06s
#
# 2019-05-01 19:39:41 (24.6 MB/s) - ‘lobinho1.jpg.1’ saved [1642262/1642262]
#
# --2019-05-01 19:39:41--  https://raw.githubusercontent.com/WittmannF/dog-breed-classifier/master/lobinho2.jpg
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 616782 (602K) [image/jpeg]
# Saving to: ‘lobinho2.jpg.1’
#
# lobinho2.jpg.1      100%[===================>] 602.33K  --.-KB/s    in 0.05s
#
# 2019-05-01 19:39:41 (11.2 MB/s) - ‘lobinho2.jpg.1’ saved [616782/616782]
#
# --2019-05-01 19:39:42--  https://raw.githubusercontent.com/WittmannF/dog-breed-classifier/master/notsure.jpg
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 600130 (586K) [image/jpeg]
# Saving to: ‘notsure.jpg.1’
#
# notsure.jpg.1       100%[===================>] 586.06K  --.-KB/s    in 0.05s
#
# 2019-05-01 19:39:42 (11.4 MB/s) - ‘notsure.jpg.1’ saved [600130/600130]
#
# --2019-05-01 19:39:43--  https://raw.githubusercontent.com/WittmannF/dog-breed-classifier/master/pug.jpg
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 377194 (368K) [image/jpeg]
# Saving to: ‘pug.jpg.1’
#
# pug.jpg.1           100%[===================>] 368.35K  --.-KB/s    in 0.04s
#
# 2019-05-01 19:39:43 (8.67 MB/s) - ‘pug.jpg.1’ saved [377194/377194]

# %%
img_path = '/home/workspace/dog_project/ca3.jpeg'

normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406],
                             std=[0.229, 0.224, 0.225])
transform = transforms.Compose([
    transforms.Resize(224),
    transforms.CenterCrop(224)
])

img = Image.open(img_path)
img = transform(img);img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F51B4666390>

# %%
predict_breed_transfer(img_path)
# Out:
# 'Silky terrier'

# %%
# !wget https://raw.githubusercontent.com/WittmannF/dog-breed-classifier/master/ca3.jpeg
# Out:
# --2019-05-01 20:04:19--  https://raw.githubusercontent.com/WittmannF/dog-breed-classifier/master/ca3.jpeg
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4689 (4.6K) [image/jpeg]
# Saving to: ‘ca3.jpeg’
#
# ca3.jpeg            100%[===================>]   4.58K  --.-KB/s    in 0s
#
# 2019-05-01 20:04:19 (87.7 MB/s) - ‘ca3.jpeg’ saved [4689/4689]

# %%
ls
# Out:
# ca2.jpg
# ca3.jpeg
# ca.jpg
# dog_app-cn.ipynb
# dog_app.ipynb
# haarcascades/
# idk.jpg
# idk.jpg.1
# images/
# labrador.jpg
# labrador.jpg.1
# lobinho1.jpg
# lobinho1.jpg.1
# lobinho2.jpg
# lobinho2.jpg.1
# lr_finder.py
# me.jpg
# model_scratch.pt
# model_transfer.pt
# notsure.jpg
# notsure.jpg.1
# NQrsW4NweYfUCA9sQJ7Z1y9cWpVrwjDA3_028Zc10GHw3A8f-1pkPCqiMW2hvRrOiajBu4_P_mbM5iJC3N07pS1rrNIgqTHz_wsJhIyxNW431bAUSg7_7XdnOno3UpC1ezu5WKGLoRdAQund_K-WIDRhqs2ES3VVixoG4cBXeLXjh5S-EXElVupRr1tKSdJYX70YQPziXYXyISs8ffLSr5-LJ3HWteFagzfiE_u06Nbp
# pug.jpg
# pug.jpg.1
# __pycache__/
# README.md

# %% [markdown]
# ---
# <a id='step5'></a>
# ## Step 5: Write your Algorithm
#
# Write an algorithm that accepts a file path to an image and first determines whether the image contains a human, dog, or neither.  Then,
# - if a __dog__ is detected in the image, return the predicted breed.
# - if a __human__ is detected in the image, return the resembling dog breed.
# - if __neither__ is detected in the image, provide output that indicates an error.
#
# You are welcome to write your own functions for detecting humans and dogs in images, but feel free to use the `face_detector` and `human_detector` functions developed above.  You are __required__ to use your CNN from Step 4 to predict dog breed.
#
# Some sample output for our algorithm is provided below, but feel free to design your own user experience!
#
# ![Sample Human Output](images/sample_human_output.png)
#
#
# ### (IMPLEMENTATION) Write your Algorithm

# %%
### TODO: Write your algorithm.
### Feel free to use as many code cells as needed.

def run_app(img_path):
    ## handle cases for a human face, dog, and neither

# %% [markdown]
# ---
# <a id='step6'></a>
# ## Step 6: Test Your Algorithm
#
# In this section, you will take your new algorithm for a spin!  What kind of dog does the algorithm think that _you_ look like?  If you have a dog, does it predict your dog's breed accurately?  If you have a cat, does it mistakenly think that your cat is a dog?
#
# ### (IMPLEMENTATION) Test Your Algorithm on Sample Images!
#
# Test your algorithm at least six images on your computer.  Feel free to use any images you like.  Use at least two human and two dog images.
#
# __Question 6:__ Is the output better than you expected :) ?  Or worse :( ?  Provide at least three possible points of improvement for your algorithm.

# %% [markdown]
# __Answer:__ (Three possible points for improvement)

# %%
## TODO: Execute your algorithm from Step 6 on
## at least 6 images on your computer.
## Feel free to use as many code cells as needed.

## suggested code, below
for file in np.hstack((human_files[:3], dog_files[:3])):
    run_app(file)
